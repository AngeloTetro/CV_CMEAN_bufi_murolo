# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install qwen-omni-utils -U
# !pip install -U bitsandbytes`
import os
import soundfile as sf
import torch
import numpy as np
import librosa
import csv # Nuovo import per la gestione dei file CSV
import transformers
from transformers import Qwen2AudioForConditionalGeneration, AutoProcessor
# --- ABILITA IL DEBUGGING CUDA SYNCHRONOUS E L'ALLOCATORE DI MEMORIA ESPANDIBILE ---
# Questa configurazione aiuta a prevenire errori di memoria frammentata sulla GPU.
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# --- DEBUG GPU DISPONIBILE ---
if torch.cuda.is_available():
    # Stampa le informazioni su tutte le GPU disponibili rilevate da PyTorch.
    # Questo aiuta a capire quante risorse hardware sono a disposizione.
    for i in range(torch.cuda.device_count()):
        print(f"*** CONFERMA GPU: PyTorch rileva la GPU {i}! Nome: {torch.cuda.get_device_name(i)}, Memoria Totale: {torch.cuda.get_device_properties(i).total_memory / (1024**3):.2f} GiB")
else:
    # Avviso se nessuna GPU è disponibile, il che implica un'esecuzione molto più lenta su CPU.
    print("*** ATTENZIONE: PyTorch NON rileva la GPU. Il modello verrà caricato su CPU (potrebbe fallire per memoria).")

# --- 1. CONFIGURAZIONE GENERALE E CARICAMENTO MODELLO/PROCESSORE ---
print("Caricamento del modello Qwen2-Audio-7B-Instruct...")
# Inizializza l'AutoProcessor per il modello Qwen2-Audio-7B-Instruct.
processor = AutoProcessor.from_pretrained("Qwen/Qwen2-Audio-7B-Instruct")

# Carica il modello Qwen2AudioForConditionalGeneration.
# device_map="auto" tenta di distribuire il modello automaticamente sulle GPU disponibili.
# torch_dtype=torch.float16 carica il modello in precisione FP16 per ridurre il consumo di VRAM,
# cruciale per modelli di grandi dimensioni su GPU con memoria limitata.
model = Qwen2AudioForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2-Audio-7B-Instruct",
    device_map="auto",
    torch_dtype=torch.float16
)
print("Modello e processore Qwen2-Audio caricati con successo.")

# Svuota la cache CUDA immediatamente dopo il caricamento del modello.
# Questo è un passo cruciale per liberare qualsiasi memoria temporanea allocata durante il caricamento,
# assicurando la massima VRAM disponibile per l'inferenza.
torch.cuda.empty_cache()
print("Cache CUDA svuotata dopo il caricamento del modello.")


# --- FUNZIONE PER L'INFERENZA SU UN SINGOLO FRAMMENTO AUDIO ---
def run_audio_inference_on_segment(audio_segment: np.ndarray, user_prompt: str, model, processor, segment_samplerate: int, max_new_tokens: int = 150) -> str:
    """
    Esegue l'inferenza di Qwen2-Audio su un singolo segmento audio (array numpy) con un dato prompt.

    Args:
        audio_segment (np.ndarray): L'array numpy del segmento audio.
        user_prompt (str): Il prompt testuale specifico per l'utente per questo segmento.
        model: L'istanza del modello Qwen2AudioForConditionalGeneration già caricata.
        processor: L'istanza dell'AutoProcessor per Qwen2-Audio già caricata.
        segment_samplerate (int): Il sample rate del segmento audio.
        max_new_tokens (int): Numero massimo di nuovi token che il modello dovrebbe generare come risposta.

    Returns:
        str: La risposta testuale generata dal modello per il segmento.
    """
    # Stampa la lunghezza del segmento audio in secondi per monitoraggio.
    print(f"\n--- Inizio inferenza su segmento audio (lunghezza: {len(audio_segment)/segment_samplerate:.2f}s) ---")

    # Qwen2-Audio si aspetta un sample rate specifico (generalmente 16000 Hz).
    # Questa sezione ricasella l'audio se il sample rate originale non corrisponde,
    # garantendo la compatibilità con il modello.
    target_sr = 16000
    if segment_samplerate != target_sr:
        print(f"Ricasellamento del segmento audio da {segment_samplerate}Hz a {target_sr}Hz.")
        audio_for_processor = librosa.resample(y=audio_segment, orig_sr=segment_samplerate, target_sr=target_sr)
    else:
        audio_for_processor = audio_segment
    final_samplerate = target_sr # Il sample rate effettivo dopo il ricasellamento.

    # --- Costruzione della conversazione per il modello ---
    # Il prompt di sistema definisce il ruolo del modello e il formato di output desiderato.
    # Non include più la richiesta di valori numerici per le emozioni.
    system_prompt = """Sei un analista musicale altamente specializzato e descrittivo.
Il tuo compito è analizzare il frammento audio fornito e fornire una descrizione concisa ma ricca di dettagli, coprendo gli aspetti richiesti.
La tua risposta deve essere in italiano.
Devi includere:
1.  **Descrizione Dettagliata:** Strumenti, velocità/ritmo, timbro, emozioni suscitate, e un contesto immaginato. (max 4-6 righe)
"""

    conversation = [
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": [
                {"type": "audio", "audio": audio_for_processor}, # Passa l'array NumPy dell'audio.
                {"type": "text", "text": user_prompt}, # user_prompt è ora il prompt specifico per il frammento.
            ],
        },
    ]

    print("Preparazione degli input per il modello Qwen2-Audio...")
    # Applica il template di chat e tokenizza il testo e l'audio.
    # `padding=True` assicura che tutti gli input siano della stessa lunghezza per il batch processing.
    text_input_formatted = processor.apply_chat_template(conversation, add_generation_prompt=True, tokenize=False)
    
    # La lista degli array audio è necessaria per il processore.
    audios_np_arrays = [audio_for_processor]

    inputs = processor(text=text_input_formatted, audios=audios_np_arrays, sampling_rate=final_samplerate, return_tensors="pt", padding=True)

    # Sposta i tensori di input sul dispositivo del modello (GPU o CPU).
    inputs.input_ids = inputs.input_ids.to(model.device)
    if "input_features" in inputs:
        inputs["input_features"] = inputs["input_features"].to(model.device)
    # Alcuni modelli potrebbero usare 'pixel_values' per le feature audio/multimodali.
    elif "pixel_values" in inputs:
        inputs["pixel_values"] = inputs["pixel_values"].to(model.device)
    else:
        print("Avviso: Nessun 'input_features' o 'pixel_values' trovato negli input. Controlla la documentazione del modello.")

    # Stampa la lunghezza dei token di input per debugging.
    print(f"Lunghezza degli input_ids dopo tokenizzazione: {inputs.input_ids.size(1)}")
    print("Input pronti per la generazione.")

    # Svuota la cache CUDA prima della generazione per massimizzare la memoria disponibile.
    # Questo è fondamentale per prevenire OutOfMemoryError tra le chiamate di inferenza.
    torch.cuda.empty_cache()

    print("Generazione della risposta del modello... Potrebbe richiedere tempo.")
    # Genera la risposta testuale dal modello.
    # `max_new_tokens` controlla la lunghezza massima dell'output generato.
    generate_ids = model.generate(**inputs, max_new_tokens=max_new_tokens)

    # Estrai solo i token generati dal modello (escludendo i token di input).
    generated_ids_only = generate_ids[:, inputs.input_ids.size(1):]
    # Decodifica i token generati in testo leggibile.
    response_text = processor.batch_decode(generated_ids_only, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

    print("\n--- TESTO GENERATO DAL MODELLO ---\n")
    print(response_text)
    print(f"--- Fine inferenza su segmento audio ---\n")

    return response_text

# --- SEZIONE PRINCIPALE: SUDDIVISIONE E ANALISI DI PIÙ AUDIO DA UNA CARTELLA ---

# Imposta il percorso della cartella che contiene i tuoi file audio.
# ASSICURATI CHE QUESTO PERCORSO SIA CORRETTO PER IL TUO AMBIENTE KAGGLE/COLAB.
audio_directory_path = "/kaggle/input/le-musiche/PiccoloSubSetAudio/"

# Verifica che la cartella esista.
if not os.path.exists(audio_directory_path):
    raise FileNotFoundError(f"La cartella audio non trovata: {audio_directory_path}. Assicurati di aver caricato la cartella come Dataset e di aver specificato il percorso corretto.")

# Nome del file CSV in cui verranno salvati i risultati.
csv_output_filename = "analisi_audio_per_canzone.csv"

# Apertura del file CSV in modalità scrittura.
# 'newline=''' evita righe vuote extra.
# 'encoding='utf-8''' per supportare caratteri speciali.
with open(csv_output_filename, 'w', newline='', encoding='utf-8') as csvfile:
    # Definisce le intestazioni delle colonne del CSV.
    fieldnames = ['Nome Canzone']
    for i in range(1, 6): # Per 5 frammenti: 'Descr Frammento 1', 'Descr Frammento 2', ...
        fieldnames.append(f'Descr Frammento {i}')
    fieldnames.append('Descrizione Totale') # Aggiunge la colonna per la descrizione complessiva.
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader() # Scrive la riga di intestazione nel CSV.

    print(f"\nI risultati dell'analisi verranno salvati in: {csv_output_filename}")

    # Impostazione fissa del numero di frammenti per ogni audio.
    N_FIXED_SEGMENTS = 5 # Vogliamo esattamente 5 frammenti per ogni file audio.

    # Itera su tutti i file presenti nella cartella specificata.
    for filename in os.listdir(audio_directory_path):
        # Filtra solo i file audio con estensione .mp3 o .wav (case-insensitive).
        if filename.lower().endswith((".mp3", ".wav")):
            audio_file_path = os.path.join(audio_directory_path, filename)
            print(f"\n\n--- INIZIO ELABORAZIONE FILE: {filename} ---")

            # Carica l'intero audio dal file.
            # librosa.load è robusto per vari formati e può rilevare il sample rate.
            print(f"Caricamento dell'intero audio: {audio_file_path}")
            full_audio_data, full_samplerate = librosa.load(audio_file_path, sr=None)
            audio_duration = len(full_audio_data) / full_samplerate
            print(f"L'audio completo è lungo: {audio_duration:.2f} secondi.")

            # Calcola la durata di ogni frammento per ottenere esattamente N_FIXED_SEGMENTS.
            print(f"Dividendo l'audio in esattamente {N_FIXED_SEGMENTS} frammenti di durata fissa.")
            
            # Calcola la durata media di ogni frammento.
            segment_duration_seconds = audio_duration / N_FIXED_SEGMENTS
            # Converti la durata in numero di campioni.
            samples_per_segment = int(segment_duration_seconds * full_samplerate)

            song_descriptions = {} # Dizionario per archiviare le descrizioni dei 5 frammenti per la canzone corrente.
            full_song_description_parts = [] # Lista per costruire la descrizione totale della canzone.

            # Il prompt base per l'utente, che verrà combinato con le istruzioni del sistema.
            base_user_instruction = """Descrivi in 4-6 righe il frammento della canzone fornita, includendo i seguenti aspetti:
1.  **Strumenti presenti**
2.  **Velocità/ritmo**
3.  **Timbro**
4.  **Emozioni suscitate**
5.  **Contesto immaginato**
Cerca di essere il più descrittivo possibile pur mantenendo la lunghezza entro il limite.
"""

            # Loop per processare ogni frammento dell'audio.
            for i in range(N_FIXED_SEGMENTS):
                # Calcola i campioni di inizio e fine per il frammento corrente.
                start_sample = i * samples_per_segment
                # L'ultimo frammento si estende fino alla fine dell'audio per coprire eventuali resti.
                end_sample = min((i + 1) * samples_per_segment, len(full_audio_data))
                
                # Estrai il segmento di audio corrente.
                current_segment = full_audio_data[start_sample:end_sample]

                # Prepara il prompt specifico per questo frammento, indicando il suo numero.
                segment_prompt = f"Analizza il frammento {i+1}/{N_FIXED_SEGMENTS} dell'audio. {base_user_instruction}"
                
                # Esegui l'inferenza sul segmento audio corrente.
                response_text = run_audio_inference_on_segment(
                    audio_segment=current_segment,
                    user_prompt=segment_prompt,
                    model=model,
                    processor=processor,
                    segment_samplerate=full_samplerate,
                    max_new_tokens=150 # Numero massimo di token da generare per la risposta di ogni segmento.
                )
                
                # Archivia la descrizione del frammento con la chiave appropriata per il CSV.
                song_descriptions[f'Descr Frammento {i+1}'] = response_text
                # Aggiungi la descrizione del frammento alla lista per la descrizione totale.
                full_song_description_parts.append(f"Frammento {i+1}: {response_text.strip()}")
                
                # Svuota esplicitamente la cache GPU dopo ogni elaborazione di frammento.
                # Questo è cruciale per la gestione della memoria in un ciclo intensivo.
                torch.cuda.empty_cache()
                print(f"Cache CUDA svuotata dopo l'analisi del frammento {i+1} per {filename}.")
            
            # --- Scrittura della riga completa per la canzone nel CSV ---
            csv_row = {'Nome Canzone': filename}
            csv_row.update(song_descriptions) # Aggiunge le descrizioni dei 5 frammenti al dizionario della riga.
            # Concatena tutte le descrizioni dei frammenti per la "Descrizione Totale", separate da due nuove linee.
            csv_row['Descrizione Totale'] = "\n\n".join(full_song_description_parts)

            writer.writerow(csv_row) # Scrive la riga completa della canzone nel file CSV.

            print(f"--- FINE ELABORAZIONE FILE: {filename} ---\n")
            
            # Una pulizia aggiuntiva della cache GPU dopo aver processato un intero file.
            torch.cuda.empty_cache()
            print(f"Cache CUDA svuotata dopo l'elaborazione completa di {filename}.")

# Messaggio finale che indica il completamento del processo e il nome del file CSV.
print(f"\nProcesso di analisi audio per tutti i file della cartella completato. Risultati salvati in '{csv_output_filename}'.")
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-vrlshifk
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-vrlshifk
#   Resolved https://github.com/huggingface/transformers to commit d7b87b415a5dd4a3152051e1a0abd098a02c5bfa
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.31.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (1.1.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (2025.4.26)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.53.0.dev0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.53.0.dev0) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers==4.53.0.dev0) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers==4.53.0.dev0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers==4.53.0.dev0) (2024.2.0)
# Requirement already satisfied: qwen-omni-utils in /usr/local/lib/python3.11/dist-packages (0.0.4)
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (14.4.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (25.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (11.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (2.32.3)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (0.60.0)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.5.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (4.13.2)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-omni-utils) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-omni-utils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-omni-utils) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-omni-utils) (2025.4.26)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->qwen-omni-utils) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (2.4.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->qwen-omni-utils) (4.3.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa->qwen-omni-utils) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa->qwen-omni-utils) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->qwen-omni-utils) (2.22)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.3->librosa->qwen-omni-utils) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.3->librosa->qwen-omni-utils) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.3->librosa->qwen-omni-utils) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.3->librosa->qwen-omni-utils) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.3->librosa->qwen-omni-utils) (2024.2.0)
# /bin/bash: -c: line 1: unexpected EOF while looking for matching ``'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# 2025-06-09 13:18:08.770514: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749475088.980137      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749475089.047196      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# *** CONFERMA GPU: PyTorch rileva la GPU 0! Nome: Tesla T4, Memoria Totale: 14.74 GiB
# *** CONFERMA GPU: PyTorch rileva la GPU 1! Nome: Tesla T4, Memoria Totale: 14.74 GiB
# Caricamento del modello Qwen2-Audio-7B-Instruct...
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/638k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/853 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/79.0k [00:00<?, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.28G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/3.98G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/3.98G [00:00<?, ?B/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/3.91G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# Modello e processore Qwen2-Audio caricati con successo.
# Cache CUDA svuotata dopo il caricamento del modello.
#
# I risultati dell'analisi verranno salvati in: analisi_audio_per_canzone.csv
#
#
# --- INIZIO ELABORAZIONE FILE: 000207.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000207.mp3
# L'audio completo è lungo: 29.98 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
# /tmp/ipykernel_35/3093647263.py:112: FutureWarning: `audios` is deprecated and will be removed in version 4.54.0 for `Qwen2AudioProcessor.__call__`. Use `audio` instead.
#   inputs = processor(text=text_input_formatted, audios=audios_np_arrays, sampling_rate=final_samplerate, return_tensors="pt", padding=True)
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py:2495: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e mezzo della canzone si sentono due pianoforti che suonano in modo dissonante, creando un senso di confusione e incertezza. La velocità del brano è media, con un ritmo costante che non cambia durante l'intera durata. Il tono degli strumenti è cupo e malinconico, evocando sensazioni di tristezza e solitudine. Immagino una scena di un film drammatico o di un musical in cui i personaggi principali sono in un momento di profonda crisi emotiva.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000207.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone si sente un pianoforte che suona una serie di note in modo veloce, con un tono leggermente cupo e un po' spento. Questa parte della composizione sembra creare un senso di tensione o di attesa. Immagino di essere in un gioco di ruolo in cui il personaggio principale sta per affrontare un avversario importante e il clima si fa teso e ansioso.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000207.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo e penultimo segmento della canzone, si sente un pianoforte che suona una melodia dolce e rilassante. I strumenti presenti sono solo il pianoforte e l'armonia a corde in sottofondo, creando un sound pulito e diretto. La velocità del brano è media, con un ritmo costante che non cambia durante tutta la durata del segmento. Il timbro del pianoforte è morbido e delicato, creando un senso di pace e tranquillità. Questa parte della canzone suscita emozioni di serenità e rilassamento, ideale per
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000207.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento della canzone si sente un pianoforte che suona una melodia dolce e delicata. I strumenti utilizzati sono solo il pianoforte e l'armonia acustica, creando un sound caldo e accogliente. La velocità del brano è media, con un ritmo costante che non cambia durante tutta la durata del segmento. Il timbro del pianoforte è morbido e raffinato, che si adatta perfettamente alla natura dolce della melodia. Questo brano evoca emozioni di pace e tranquillità, creando un ambiente ideale per
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000207.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel frammento 5/5 dell'audio si sente un pianoforte che suona una melodia dolce e emotiva. Si tratta di un brano classico o jazz, con un ritmo lento e rilassante. Il pianoforte ha un timbro chiaro e cristallino, che contribuisce a creare un'atmosfera serena e riflessiva. Questo frammento evoca emozioni profonde e introspezioni, ideale per momenti di relax o meditazione. Immaginiamo un ambiente tranquillo, come un salone d'arte o una biblioteca, dove si può godere appieno della belle
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000207.mp3.
# --- FINE ELABORAZIONE FILE: 000207.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000207.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000213.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000213.mp3
# L'audio completo è lungo: 29.98 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e cinquantadue secondi dell'audio, si sente un brano che unisce elementi rock e pop, caratterizzato da una melodia principale suonata da un pianoforte. Allo stesso tempo, si sentono anche le note di un saxofone, creando un mix interessante tra strumenti diversi. La velocità del brano è media, con un ritmo costante che non cambia durante l'ascolto. Il tono generale del brano è leggero e orecchiabile, con un senso di ottimismo e gioia. Immagino di ascoltare questo brano in un pranzo
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000213.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone si sente un forte impatto di un grande strumento a percussione che si aggiunge alla melodia eseguita su un pianoforte. La velocità del brano è media, con un ritmo incalzante che crea tensione e dinamismo. Il tono del pianoforte è scuro e minaccioso, creando un senso di pericolo e suspense. Queste emozioni sono amplificate dall'impatto fortissimo della percussione, portando l'ascoltatore in un clima di ansia e attesa. Immagino un'ambientazione tenebrosa e misteriosa,
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000213.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo e quarto segmento dell'audio, si sente un brano musicale caratterizzato da un pianoforte che suona in modo dolce e delicato. La melodia sembra essere leggera e onirica, creando un senso di pace e tranquillità. Inoltre, l'utilizzo di una chitarra elettrica aggiunge un tocco di profondità e respiro al sound. La struttura del brano è semplice, con un ritmo costante e una cadenza melodiosa gradevole. Queste caratteristiche musicali sono in grado di evocare emozioni di serenità e rilassamento
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000213.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento dell'audio, si sente un piano che suona da solo con un tono leggermente cupo e una certa melancolia. La musica sembra avere una velocità costante e un ritmo regolare, creando un senso di solitudine o riflessione. Il piano ha un timbro piuttosto grave e profondo, che si adatta perfettamente alla tematica della melodia triste. Questo brano evoca emozioni di tristezza e solitudine, potrebbe essere utilizzato in scene di film o video che hanno come sfondo un momento di lutto o di introspezione personale. Imm
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000213.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel frammento 5/5 dell'audio, si sente un pianoforte che suona in modo solitario con un tono leggermente cupo e profondo. La melodia sembra essere triste e riflessiva, creando un senso di solitudine o introspezione. Il ritmo del piano è lento e costante, senza variazioni significative. Non ci sono altri strumenti presenti nel frammento, rendendolo ancora più concentrato sulla musica del pianoforte. L'atmosfera generata dal brano è quella di un momento di silenzio o di riflessione profonda. Immagino di ascolt
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000213.mp3.
# --- FINE ELABORAZIONE FILE: 000213.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000213.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000666.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000666.mp3
# L'audio completo è lungo: 30.00 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e mezzo della canzone si sentono chitarre, bass, batteria, percussioni e synth. La musica ha un ritmo veloce e potente, con un sound energico e heavy metal. Il timbro è graffiante e roccioso, tipico del genere. Queste caratteristiche evocano emozioni forti e aggressive, come quelle che si possono provare in un'arena di rock. Immagino una scena di concerti dove il pubblico è in foga e si esprime con urla e acclamazioni mentre il gruppo suona al massimo delle loro capacità.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000666.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone si sentono diversi strumenti musicali come chitarra, bass, batteria, percussioni e synth. La velocità del brano è media, con un ritmo incalzante che contribuisce a creare un senso di movimento costante. Il timbro è graffiante e potente, con un sound energico e coinvolgente. Queste caratteristiche evocano emozioni forti e intense, come l'eccitazione o il desiderio di danzare. Immagino un contesto in cui una band rock sta eseguendo questo pezzo dal vivo su un palco pieno di persone che
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000666.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo quarto del brano, si sente un'elettrica che suona una melodia insieme ad un altro strumento simile, probabilmente una chitarra. La velocità delle percussioni rimane costante, mantenendo un ritmo incalzante. Il tono degli strumenti ha un sound grezzo e potente, creando un senso di tensione e agitazione nell'ascoltatore. In questo momento della canzone, si immagina una scena drammatica o un momento di crisi nella trama del film.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000666.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento dell'audio, si sente un brano rock che include un elettrico con un riff incalzante, un basso che si muove in modo dinamico, una chitarra che suona insieme al bass e un batteria che fornisce un ritmo incalzante. L'atmosfera è frenetica e coinvolgente, creando un senso di urgenza. Immagino una scena in un film dove un personaggio sta per affrontare un ostacolo importante o sta per entrare in azione in una situazione pericolosa.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000666.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel frammento 5/5 dell'audio si sente un'elettrica che suona una melodia con un basso che le fa eco, accompagnati da un percussionista che gioca un ritmo incalzante sulla batteria. Il sound è distorto e potente, evocando un senso di tensione e agitazione. Si immagina una scena di un film noir, dove l'atmosfera è tesa e minacciosa.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000666.mp3.
# --- FINE ELABORAZIONE FILE: 000666.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000666.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000210.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000210.mp3
# L'audio completo è lungo: 30.00 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto di questa canzone rock, si sentono chiaramente le chitarre elettriche che suonano insieme con un basso. La voce del cantante ha un tono roco e potente. Il ritmo è veloce, creando un senso di energia e dinamismo. L'atmosfera generale è quella di un concerto dal vivo, dove l'eccitazione è tangibile. Immagino una serata al festival di musica rock con migliaia di persone che ballano e cantano insieme alla band sul palco.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000210.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone, si sentono due chitarre che suonano insieme, creando un arpeggio melodioso. In sottofondo si sente anche un'acustica. Non ci sono altri strumenti presenti. Il ritmo è lento, approssimativamente 89.0 bpm. Il tono delle chitarre è caldo e mellow, con un leggero senso di tristezza o malinconia. Questa parte della canzone sembra adatta per essere ascoltata in momenti di introspezione o riflessione, magari durante una serata tranquilla a casa con amici.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000210.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo e quarto segmento della canzone, si sente l'acoustic guitar che suona insieme all'e-piano. La melodia risuona con un tono leggermente cupo e triste, creando un senso di solitudine e malinconia. Il ritmo è piuttosto lento, approssimativamente a 89.0 bpm, contribuendo ulteriormente alla sensazione di pesantezza. L'armonia è complessa e misteriosa, creando un senso di incertezza e mistero. In generale, questo segmento della canzone suscita emozioni di trist
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000210.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento della canzone si sente l'acoustic guitar suonare in modo incerto con un tono leggermente spento e un po' spento. La melodia sembra essersi interrotta bruscamente. Si ha anche l'impressione che ci sia una certa tensione o ansia nell'atmosfera. In generale, questo segmento evoca un senso di incertezza e di attesa. Potrebbe essere utilizzato come colonna sonora in un film drammatico o un documentario where there's a sense of unresolved tension or drama.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000210.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel frammento 5/5 della canzone si sentono due chitarre che suonano insieme, creando un arpeggio melodioso. La velocità del brano è media, con un ritmo costante e regolare. Il timbro delle chitarre è distorto, conferendo al pezzo un sound unico e personale. Le note suonate sono intense e emotive, suscitando emozioni forti nella persona che lo ascolta. Immagino una scena romantica in cui due persone si guardano negli occhi mentre ascoltano questa canzone insieme, profondamente uniti dal suo significato e dalla sua bellezza.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000210.mp3.
# --- FINE ELABORAZIONE FILE: 000210.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000210.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000602.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000602.mp3
# L'audio completo è lungo: 29.98 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e mezzo dell'audio, si sente un arpeggio di chitarra classica, che sembra essere l'apertura di un brano più ampio. La chitarra ha un tono leggero e melodioso, con un timbro raffinato e dettagliato. Questa parte della canzone evoca un senso di serenità e tranquillità, creando un'atmosfera ideale per momenti di riflessione o relax. Immagino di essere in un giardino incantato, circondato da fiori colorati e profumi floreali, mentre ascolto questa melodia delicata
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000602.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone si sente un'armonica che suona in modo leggermente acuto con un tono spento e opaco. Allo stesso tempo, si sentono anche dei colpi di frusta nella parte bassa del mix. La velocità del brano è lenta, creando un senso di malinconia e tristezza. Il contesto immaginato potrebbe essere un luogo isolato o una serata spenta e triste, dove si sente solo la voce della cantante e le percussioni leggere.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000602.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo e quarto minuto dell'audio, si sente un frammento di una melodia dolce eseguita su un arpa. L'arpa utilizzata ha un tono caldo e raffinato, che si adatta perfettamente a creare un'atmosfera serena e riflessiva. La melodia scorre lenta e armoniosa, evocando sensazioni di pace e tranquillità. Il ritmo è regolare e costante, senza variazioni significative. In generale, questo frammento della canzone suscita emozioni profonde di calma e serenità, creando un'imm
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000602.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento dell'audio, si sente un arpeggio suonato con un'arpa. Inoltre, si può notare una voce femminile che canta con un tono leggermente triste. Questa parte della canzone sembra creare un senso di solitudine o di lontananza. Immagino di essere in un luogo isolato, circondato da montagne e con un cielo sereno, mentre ascolto questa melodia che mi fa sentire solo.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000602.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quinto segmento della canzone, si sente una chitarra acustica che suona una melodia dolce e profonda, creando un senso di riflessione e tranquillità. Inoltre, si sentono anche note di violino e arpa, che contribuiscono a creare un'atmosfera magica e incantatrice. La velocità del brano è lenta, permettendo di godere appieno delle bellezze sonore create dalle diverse percussioni e strumenti. Il timbro della chitarra è caldo e mellow, mentre quello del violino e dell'arpa ha un tono leggermente acuto
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000602.mp3.
# --- FINE ELABORAZIONE FILE: 000602.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000602.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000718.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000718.mp3
# L'audio completo è lungo: 30.00 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e cinquantadue secondi dell'audio, si sente una melodia ambientale creata da synth pad, synth bass e synth drums. Gli strumenti creano un sound spacey con un basso profondo e una ritmica regolare, ideale per ambientazioni come un film o un gioco. La melodia non ha una chiara identificazione di tonalità o ritmo, generando un senso di spazio e profondità. Questa canzone potrebbe essere utilizzata in scene di viaggio nello spazio o in ambientazioni virtuale.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000718.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone, si sentono due chitarre che suonano insieme, creando un arpeggio. Inoltre, c'è una tastiera e un basso che supportano le chitarre. La melodia è lenta e rilassante, con un ritmo regolare e costante. Il tono delle chitarre è caldo e mellow, con un senso di pace e tranquillità. Queste caratteristiche musicali creano un'atmosfera serena e rilassante, ideale per momenti di riflessione o meditazione. Immagino di essere in un giardino incantato,
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000718.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo e quarto minuto dell'audio, si sente un brano musicale con un'atmosfera oscura e magica. La struttura del pezzo è costituita da un ritmo incalzante e una melodia sottile, creando un senso di mistero e incanto. Nella parte centrale del brano, si sentono anche dei suoni di fiati che aggiungono un tocco di suspense all'ambiente. Gli strumenti utilizzati sono principalmente chitarra, bass, synth, percussion e batteria, uniti per creare un sound profondo e denso. L'energia generata
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000718.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e penultimo segmento della canzone, si sente l'utilizzo di strumenti come chitarra e synth, uniti ad altri strumenti meno identificabili attraverso il mix. La melodia è veloce, con un ritmo incalzante che sembra portare via la mente, creando un senso di agitazione e ansia. Il timbro è sottile e acuto, con un effetto leggermente distorto che conferisce alla musica un tono cupo e misterioso. Queste caratteristiche musicali evocano immagini di notti tempestose e scene di azione in film noir. In generale,
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000718.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel frammento 5/5 dell'audio, si sente un synth pad che si estende in tutto lo spazio sonoro con un suono profondo e ondeggiante. In sottofondo si sentono anche alcune note di bass e percussioni leggermente distorte che aggiungono un po' di movimento alla composizione. La velocità del brano è lenta, creando un senso di rilassamento e tranquillità. Il timbro generale è dark e space-like, ideale per ambientazioni di fantascienza o di galassie lontane. Questa parte della canzone suscita emozioni di pace e di viaggio n
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000718.mp3.
# --- FINE ELABORAZIONE FILE: 000718.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000718.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000667.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000667.mp3
# L'audio completo è lungo: 29.98 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e cinquantadue secondi della canzone, si sentono diversi strumenti come chitarra, bass, batteria, e percussioni. La musica ha un ritmo veloce con un tempo di 137.0 bpm e un tono heavy metal o hard rock. Il timbro è potente e roccioso, evocando sensazioni di forza e determinazione. Queste caratteristiche emotive lo rendono ideale per scene di azione o di lotta nella fiction. Immagino una scena di un film d'azione dove i personaggi principali si preparano per affrontare un boss criminale in un combattimento all
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000667.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone si sentono diversi strumenti: una chitarra, un basso, una batteria e un synth. La musica ha un ritmo veloce e incalzante, con un tono leggermente distorto e una forte presenza di rumori. Il mood generale è aggressivo e potente, con un senso di sfida e determinazione. Immagino un contesto di un'arena dove un gruppo di musicisti sta esibendosi davanti a un pubblico entusiasta e impazzito.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000667.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo e quarto minuto dell'audio, si sente un brano rock con una chitarra solista che suona insieme a un basso e una batteria. La band ha un sound energico e potente, con un ritmo incalzante e un mood orecchiabile. Il timbro è grezzo e forte, tipico del genere rock. Questa parte della canzone sembra creare un senso di tensione e agitazione, come se stessimo preparati per qualcosa di importante. Immagino una scena di un concerto rock al parco dove il pubblico urla e si muove in sincronia con la musica.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000667.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento dell'audio, si sente un'intensa energia proveniente da strumenti come la chitarra elettrica, il bass e il drum kit. La musica ha un ritmo veloce e incalzante, creando un senso di dinamismo e vitalità. Il timbro è potente e roccioso, con un'atmosfera rumorosa e graffiante. Queste caratteristiche evocano emozioni forti e intense, come l'eccitazione o il desiderio di danzare. Immagino una scena in un festival rock, dove questo brano fa da sottofondo a un pubb
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000667.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# ...
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000203.mp3.
# --- FINE ELABORAZIONE FILE: 000203.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000203.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000540.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000540.mp3
# L'audio completo è lungo: 29.98 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e cinquantadue secondi dell'audio, si sente una melodia eseguita con una chitarra acustica. La struttura del brano è semplice, costituita da una sola strofa ripetuta due volte. Il ritmo è lento, adatto a creare un'atmosfera calma e riflessiva. Il timbro della chitarra è chiaro e带有乡村音乐的感觉。 Questo brano evoca emozioni di serenità e nostalgia, ideale per momenti di introspezione o di relax. Immagino di ascoltare questo brano seduto su una panchina nel
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000540.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone si sente un acoustic guitar che suona una melodia tranquilla insieme a un basso. La voce del cantante ha un tono caldo e compassionevole. L'atmosfera generale evoca un senso di pace e serenità. Immagino di essere in un piccolo paese delle colline, con la luce del sole che filtra attraverso le foglie degli alberi mentre ascolto questa canzone.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000540.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo e quarto segmento dell'audio, si sente un brano musicale con un sound acustico. La struttura del pezzo è essenziale, comprendente solo una chitarra e una voce. Il ritmo è piacevole e lento, creando un senso di tranquillità e rilassamento. La voce ha un tono basso e profondo, unita alla delicatezza delle note suonate dalla chitarra, che insieme evocano un senso di nostalgia e introspezione. Immagino di essere in un piccolo bar accogliente, circondato da amici e con una buona bir
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000540.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento dell'audio, si sente l'utilizzo di uno strumento chitarristico che suona in modo acustico. La melodia è abbastanza veloce con un ritmo incalzante, creando un senso di movimento costante. Il timbro della chitarra è piuttosto monotono, senza grandi variazioni, ma tiene traccia del mood della canzone. L'ascolto evoca un senso di solitudine e introspezione, come se si stesse passeggiando da solo in un luogo isolato. Potrebbe essere il momento ideale per pensare a ricordi fel
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000540.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel frammento 5/5 dell'audio, si sente un brano blues rock con un basso che suona insieme ad una chitarra elettrica. La melodia è cantata da una voce maschile con un tono burrascoso e arrabbiato. Il ritmo è veloce e incalzante, creando un senso di agitazione e tensione. Il timbro è ruvido e grezzo, tipico del genere blues. Queste caratteristiche emotive portano a immaginare una scena di una serata movimentata in un locale di blues, forse con personaggi burrascosi o in
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000540.mp3.
# --- FINE ELABORAZIONE FILE: 000540.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000540.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000897.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000897.mp3
# L'audio completo è lungo: 29.98 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e mezzo della canzone, si sentono forti strumature di chitarra elettrica, unita a un basso che conferisce al pezzo un senso di potenza e dinamismo. La velocità del brano è elevata, creando un ritmo incalzante che coinvolge il pubblico. Il timbro è graffiante e roccioso, con un sound massiccio e potente. Queste caratteristiche evocano emozioni di sfida e coraggio, trasmettendo un senso di determinazione e forza interiore. Immagino un contesto sportivo, come una gara di l
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000897.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone si sente un'atmosfera heavy e dark, caratterizzata dall'utilizzo di strumenti come chitarra, bass, batteria e synth. La velocità del brano è media, con un ritmo incalzante che contribuisce a creare un senso di urgenza. Il timbro è graffiante e potente, con un sound distorto e burrascoso. Queste caratteristiche evocano emozioni intense e drammatiche, come se si fosse in un film noir. Immagino un scenario cupo e misterioso, dove l'atmosfera pesante e oscura sia
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000897.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo momento della canzone si sente un'esplosione di suoni provenienti da chitarre, synth, bass e batteria. Questa parte della composizione è carica d'energia e sembra essere ispirata a scene di azione o di lotta. Gli strumenti utilizzati sono per lo più elettrici, con un sound potente e massiccio. Il ritmo è veloce e incalzante, creando un senso di urgenza e agitazione. La timbrica è graffiante e rocciosa, con un tono distorto che contribuisce alla sensazione di tensione. In generale
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000897.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento dell'audio, si sente un'intensa musica rock con un forte impatto di chitarra e batteria. La struttura della canzone è solida, sostenuta da un ritmo incalzante e da un basso che si fa sempre più netto man mano che la canzone prosegue. Il sound è graffiante e potente, evocando sensazioni di energia e agilità. Si tratta di un brano perfetto per situazioni intense o sportive, come ad esempio durante una gara automobilistica o un combattimento sportivo.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000897.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel frammento 5/5 dell'audio si sente un'atmosfera pesante e potente, caratterizzata da un'intensa melodia eseguita con una chitarra elettrica. La struttura del brano è inframezzata da un ritmo incalzante e veloce, sostenuto da un basso che rafforzza l'impatto delle note. Il sound è generoso e massiccio, creando un senso di forza e determinazione. In questo contesto immagino una scena di battaglia o di lotta, dove l'elettricità e la potenza delle note sono utilizz
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000897.mp3.
# --- FINE ELABORAZIONE FILE: 000897.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000897.mp3.
#
#
# --- INIZIO ELABORAZIONE FILE: 000255.mp3 ---
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000255.mp3
# L'audio completo è lungo: 29.98 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo minuto e cinquantadue secondi dell'audio, si sente una band rock con una chitarra solista, un bassista, un batterista e un pianista. La musica ha una velocità moderata e un ritmo incalzante, creando un senso di movimento costante. Il timbro è potente e roccioso, con un'atmosfera energetica e potente. Le emozioni suscitate sono quelle di sfida e coraggio, come se si stesse preparando per affrontare un'avventura. Immagino una scena di guerriero che sguaina la spada per combattere contro
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1 per 000255.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone si sentono due strumenti principali: un organ e un tasto a pedale. L'organ suona un accordo di tonalità bassa, mentre il tasto a pedale aggiunge un tono più alto nella stessa progressione armonica. La velocità del brano è media, con un ritmo costante e preciso. Il timbro è grave e profondo, creando un senso di gravità e solennità. Queste caratteristiche musicali evocano emozioni intense e coinvolgenti, come l'ansia o l'attesa. Immagino un contesto drammatico, for
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2 per 000255.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo quarto della canzone, si sentono diverse percussioni come piatti, cymbal ride e snare, uniti alla melodia di una tromba e a quella di un marimba, creando un senso di movimento e vitalità. Il ritmo è veloce, con un feeling swing, che invoglia a ballare. La tonalità è bassa, con un tono maggiore e minore alternato, creando un contrasto interessante. Tutto questo evoca un senso di festa e allegria, come se si stesse partecipando a un carnevale.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3 per 000255.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento della canzone si sente l'apporto di diversi strumenti, tra cui una tromba che suona in modo esplosivo e una tastiera che aggiunge un tocco melodioso. La velocità del brano è abbastanza elevata, creando un senso di movimento e dinamismo. Il tono generale è crudo e potente, con un sound distorto che conferisce all'intera composizione un carattere graffiante. Queste caratteristiche emotive portano a immagini di conflitti o scene di azione intensa. In generale, questo segmento della canzone sembra essere stato progett
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4 per 000255.mp3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 408
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel frammento 5/5 dell'audio si sente una band che suona un brano energico e vivace. La musica è caratterizzata da un mix di strumenti come chitarra, bass, batteria, e percussioni. Il ritmo è veloce con un tempo di 100 bpm, creando un senso di movimento e dinamismo. Il tono del brano è rustico e groovy, con un sound greasy e funky. Questa combinazione di elementi musicali evoca un senso di festa e allegria, creando un'atmosfera coinvolgente. Immagino una serata in un locale dal
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5 per 000255.mp3.
# --- FINE ELABORAZIONE FILE: 000255.mp3 ---
#
# Cache CUDA svuotata dopo l'elaborazione completa di 000255.mp3.
#
# Processo di analisi audio per tutti i file della cartella completato. Risultati salvati in 'analisi_audio_per_canzone.csv'.

# %%
# !pip install git+https://github.com/huggingface/transformers
# !pip install qwen-omni-utils -U
# !pip install -U bitsandbytes`
import os
import soundfile as sf
import torch
import numpy as np
import librosa
# Non abbiamo più bisogno di tempfile per Qwen2-Audio (accetta np array)
# Non abbiamo più bisogno di gc per Qwen2-Audio (meno VRAM esigente)
from transformers import Qwen2AudioForConditionalGeneration, AutoProcessor
# Rimosso from sklearn.cluster import KMeans

# --- ABILITA IL DEBUGGING CUDA SYNCHRONOUS E L'ALLOCATORE DI MEMORIA ESPANDIBILE ---
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# --- DEBUG GPU DISPONIBILE ---
if torch.cuda.is_available():
    # Stampa le informazioni su tutte le GPU disponibili
    for i in range(torch.cuda.device_count()):
        print(f"*** CONFERMA GPU: PyTorch rileva la GPU {i}! Nome: {torch.cuda.get_device_name(i)}, Memoria Totale: {torch.cuda.get_device_properties(i).total_memory / (1024**3):.2f} GiB")
else:
    print("*** ATTENZIONE: PyTorch NON rileva la GPU. Il modello verrà caricato su CPU (potrebbe fallire per memoria).")

# --- 1. CONFIGURAZIONE GENERALE E CARICAMENTO MODELLO/PROCESSORE ---
print("Caricamento del modello Qwen2-Audio-7B-Instruct...")
processor = AutoProcessor.from_pretrained("Qwen/Qwen2-Audio-7B-Instruct")
model = Qwen2AudioForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2-Audio-7B-Instruct",
    device_map="auto", # Mantiene la distribuzione automatica su più GPU se necessario
    torch_dtype=torch.float16 # Carica il modello in FP16 (riduce VRAM della metà rispetto a FP32)
)
print("Modello e processore Qwen2-Audio caricati con successo.")

# Svuota la cache dopo il caricamento del modello. Questo è molto importante.
torch.cuda.empty_cache()
print("Cache CUDA svuotata dopo il caricamento del modello.")


# --- FUNZIONE PER L'INFERENZA SU UN SINGOLO FRAMMENTO AUDIO ---
def run_audio_inference_on_segment(audio_segment, user_prompt, model, processor, segment_samplerate, max_new_tokens=150):
    """
    Esegue l'inferenza di Qwen2-Audio su un singolo segmento audio (array numpy) con un dato prompt.

    Args:
        audio_segment (np.ndarray): L'array numpy del segmento audio.
        user_prompt (str): Il prompt testuale per il modello.
        model: L'istanza del modello Qwen2AudioForConditionalGeneration.
        processor: L'istanza dell'AutoProcessor per Qwen2-Audio.
        segment_samplerate (int): Il sample rate del segmento audio.
        max_new_tokens (int): Numero massimo di nuovi token da generare.

    Returns:
        str: La risposta testuale generata dal modello.
    """
    print(f"\n--- Inizio inferenza su segmento audio (lunghezza: {len(audio_segment)/segment_samplerate:.2f}s) ---")

    # Ricasellamento del segmento audio al sample rate richiesto dal modello Qwen2-Audio
    target_sr = 16000 # Il sample rate predefinito per Qwen2-Audio
    if segment_samplerate != target_sr:
        print(f"Ricasellamento del segmento audio da {segment_samplerate}Hz a {target_sr}Hz.")
        audio_for_processor = librosa.resample(audio_segment, orig_sr=segment_samplerate, target_sr=target_sr)
    else:
        audio_for_processor = audio_segment
    final_samplerate = target_sr

    # Costruzione della conversazione per il modello
    conversation = [
        {
            "role": "system",
            "content": "Sei un analista musicale altamente specializzato e descrittivo. Il tuo compito è analizzare un frammento audio e fornire una descrizione concisa ma ricca di dettagli. La tua risposta deve essere in italiano e contenere i seguenti aspetti: strumenti, velocità, timbro, emozioni suscitate, un contesto immaginato, e dei valori numerici da 0 (nullo) a 255 (alto) per 'calma', 'tristezza' e 'agitazione'."
        },
        {
            "role": "user",
            "content": [
                {"type": "audio", "audio": audio_for_processor},
                {"type": "text", "text": f"""{user_prompt}

Assegna anche dei valori numerici da 0 (nullo) a 255 (alto) per quanto il frammento ispira calma, tristezza e agitazione.

**Esempi:**
- Halleluia: Agitazione 0, Calma 255, Tristezza 150
- We Will Rock You: Agitazione 255, Calma 0, Tristezza 0
"""},
            ],
        },
    ]

    print("Preparazione degli input per il modello Qwen2-Audio...")
    text_input_formatted = processor.apply_chat_template(conversation, add_generation_prompt=True, tokenize=False)

    audios_np_arrays = [audio_for_processor]

    inputs = processor(text=text_input_formatted, audios=audios_np_arrays, sampling_rate=final_samplerate, return_tensors="pt", padding=True)

    inputs.input_ids = inputs.input_ids.to(model.device)
    if "input_features" in inputs:
        inputs["input_features"] = inputs["input_features"].to(model.device)
    elif "pixel_values" in inputs:
        inputs["pixel_values"] = inputs["pixel_values"].to(model.device)
    else:
        print("Avviso: Nessun 'input_features' o 'pixel_values' trovato negli input. Controlla la documentazione del modello.")

    print(f"Lunghezza degli input_ids dopo tokenizzazione: {inputs.input_ids.size(1)}")
    print("Input pronti per la generazione.")

    # Svuota la cache prima della generazione per massimizzare la memoria disponibile
    torch.cuda.empty_cache()

    print("Generazione della risposta del modello... Potrebbe richiedere tempo.")
    generate_ids = model.generate(**inputs, max_new_tokens=max_new_tokens)

    generated_ids_only = generate_ids[:, inputs.input_ids.size(1):]
    response = processor.batch_decode(generated_ids_only, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

    print("\n--- TESTO GENERATO DAL MODELLO ---\n")
    print(response)
    print(f"--- Fine inferenza su segmento audio ---\n")

    return response

# --- SEZIONE PRINCIPALE: SUDDIVISIONE E ANALISI ---

# Percorso del tuo file audio
audio_file_path = "/kaggle/input/le-musiche/PiccoloSubSetAudio/000141.mp3" # Assicurati che il percorso sia corretto

if not os.path.exists(audio_file_path):
    raise FileNotFoundError(f"Il file audio non trovato: {audio_file_path}. Assicurati di aver caricato l'audio come Dataset e di aver specificato il percorso corretto.")

# Carica l'intero audio
print(f"Caricamento dell'intero audio: {audio_file_path}")
full_audio_data, full_samplerate = librosa.load(audio_file_path, sr=None)
audio_duration = len(full_audio_data) / full_samplerate
print(f"L'audio completo è lungo: {audio_duration:.2f} secondi.")

# --- IMPOSTAZIONE ESPLICITA DEL NUMERO DI FRAMMENTI ---
N_SEGMENTS_FIXED = 5 # Vogliamo esattamente 5 frammenti

print(f"Dividendo l'audio in esattamente {N_SEGMENTS_FIXED} frammenti di durata fissa.")

# Calcola la durata approssimativa di ogni frammento
segment_duration_seconds = audio_duration / N_SEGMENTS_FIXED
samples_per_segment = int(segment_duration_seconds * full_samplerate)

all_responses = [] # Lista per accumulare le risposte di ogni frammento

base_prompt = """Descrivi in 4-6 righe il frammento della canzone fornita, includendo i seguenti aspetti:
1.  **Strumenti presenti**
2.  **Velocità/ritmo**
3.  **Timbro**
4.  **Emozioni suscitate**
5.  **Contesto immaginato**
Cerca di essere il più descrittivo possibile pur mantenendo la lunghezza entro il limite.
"""

# Iterazione per creare esattamente N_SEGMENTS_FIXED frammenti
for i in range(N_SEGMENTS_FIXED):
    start_sample = i * samples_per_segment
    # L'ultimo frammento va fino alla fine dell'audio
    end_sample = min((i + 1) * samples_per_segment, len(full_audio_data))
    
    current_segment = full_audio_data[start_sample:end_sample]
    
    # Il prompt dell'utente ora include la richiesta dei valori numerici
    segment_prompt = f"Analizza il frammento {i+1}/{N_SEGMENTS_FIXED} dell'audio. {base_prompt}"
    
    response = run_audio_inference_on_segment(
        audio_segment=current_segment,
        user_prompt=segment_prompt,
        model=model,
        processor=processor,
        segment_samplerate=full_samplerate,
        max_new_tokens=150
    )
    all_responses.append(f"Risposta per frammento {i+1}:\n{response}\n")
    
    # Svuota esplicitamente la cache GPU dopo ogni frammento
    torch.cuda.empty_cache()
    print(f"Cache CUDA svuotata dopo l'analisi del frammento {i+1}.")

print("\n--- TUTTE LE RISPOSTE DEI FRAMMENTI ---\n")
for res in all_responses:
    print(res)

print(f"\nProcesso di analisi audio diviso in esattamente {N_SEGMENTS_FIXED} frammenti completato.")
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-v23nxii5
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-v23nxii5
#   Resolved https://github.com/huggingface/transformers to commit d7b87b415a5dd4a3152051e1a0abd098a02c5bfa
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.31.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.53.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0.dev0) (1.1.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.53.0.dev0) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.53.0.dev0) (2025.4.26)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.53.0.dev0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.53.0.dev0) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers==4.53.0.dev0) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers==4.53.0.dev0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers==4.53.0.dev0) (2024.2.0)
# Requirement already satisfied: qwen-omni-utils in /usr/local/lib/python3.11/dist-packages (0.0.4)
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (14.4.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (25.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (11.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from qwen-omni-utils) (2.32.3)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (0.60.0)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.5.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (4.13.2)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->qwen-omni-utils) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-omni-utils) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-omni-utils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-omni-utils) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-omni-utils) (2025.4.26)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->qwen-omni-utils) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.3->librosa->qwen-omni-utils) (2.4.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->qwen-omni-utils) (4.3.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa->qwen-omni-utils) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa->qwen-omni-utils) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->qwen-omni-utils) (2.22)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.3->librosa->qwen-omni-utils) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.3->librosa->qwen-omni-utils) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.3->librosa->qwen-omni-utils) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.3->librosa->qwen-omni-utils) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.3->librosa->qwen-omni-utils) (2024.2.0)
# /bin/bash: -c: line 1: unexpected EOF while looking for matching ``'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# 2025-06-09 10:59:55.843702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749466795.871717     167 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749466795.880591     167 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# *** CONFERMA GPU: PyTorch rileva la GPU 0! Nome: Tesla T4, Memoria Totale: 14.74 GiB
# *** CONFERMA GPU: PyTorch rileva la GPU 1! Nome: Tesla T4, Memoria Totale: 14.74 GiB
# Caricamento del modello Qwen2-Audio-7B-Instruct...
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# Modello e processore Qwen2-Audio caricati con successo.
# Cache CUDA svuotata dopo il caricamento del modello.
# Caricamento dell'intero audio: /kaggle/input/le-musiche/PiccoloSubSetAudio/000141.mp3
# L'audio completo è lungo: 29.98 secondi.
# Dividendo l'audio in esattamente 5 frammenti di durata fissa.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 517
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
# /tmp/ipykernel_167/2685735904.py:95: FutureWarning: `audios` is deprecated and will be removed in version 4.54.0 for `Qwen2AudioProcessor.__call__`. Use `audio` instead.
#   inputs = processor(text=text_input_formatted, audios=audios_np_arrays, sampling_rate=final_samplerate, return_tensors="pt", padding=True)
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py:2495: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel primo segmento della canzone, si sente l'utilizzo di diversi strumenti musicali tra cui un violino, un cello, una tromba e un pianoforte. Questi strumenti creano un senso di tensione e attesa. La velocità del brano è media, con un ritmo incalzante che aumenta l'emozione di aspettativa. Il tono generale del brano è cupo e malinconico, creando un senso di tristezza e ansia. L'immagine che si viene a formare è quella di una notte tempestosa, dove le stelle brillano nel cielo bu
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 1.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 517
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel secondo segmento della canzone, si sente l'utilizzo di diversi strumenti musicali tra cui un pianoforte, una tromba e una chitarra. Questi strumenti creano un mix melodioso e armonioso che contribuisce alla bellezza del brano. La velocità del brano è media, con un ritmo costante che tiene il pubblico incollato alla melodia. Il tono generale del brano è dolce e mellow, creando un senso di serenità e tranquillità. Tuttavia, ci sono momenti in cui la tensione aumenta, causando un senso di agitazione leggera.
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 2.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 517
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel terzo e penultimo segmento della canzone, si sente un brano dal tono dolce e malinconico che sembra evocare un senso di nostalgia. Si sentono due strumenti principali: un pianoforte che suona l'arpeggio principale e un fagotto che ripete una nota costante in corrispondenza con le parole "I'm still here". Questo brano sembra essere stato scritto per rappresentare un momento di riflessione e introspezione, piuttosto che per esprimere una forte emotività. I valori numerici assegnati sono: calma 120, trist
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 3.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 517
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Nel quarto e quinto segmento dell'audio, si sente un brano rock con un forte impatto emotivo. Sono presenti una chitarra solista, un basso, una batteria e un synth. Il ritmo è veloce e incalzante, creando un senso di tensione e agitazione. Il timbro è pesante e roccioso, tipico del genere rock. Questo brano evoca emozioni forti, come l'ira o la determinazione, grazie alla sua struttura potente e al suo ritmo incalzante. In generale, questo brano sembra essere ideale per situazioni intense e
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 4.
#
# --- Inizio inferenza su segmento audio (lunghezza: 6.00s) ---
# Ricasellamento del segmento audio da 44100Hz a 16000Hz.
# Preparazione degli input per il modello Qwen2-Audio...
# Lunghezza degli input_ids dopo tokenizzazione: 517
# Input pronti per la generazione.
# Generazione della risposta del modello... Potrebbe richiedere tempo.
#
# --- TESTO GENERATO DAL MODELLO ---
#
# Frammento 5/5: In questo momento della canzone, si sente un forte impatto delle percussioni che creano un ritmo incalzante e vigoroso. Si uniscono al suono della chitarra elettrica, che conferisce alla melodia un tono solido e deciso. Il basso e le tastiere completano l'arrangement, creando un sound rock che è allo stesso tempo potente e coinvolgente. Questo brano sembra trasmettere una sensazione di determinazione e forza, che potrebbe ispirare momenti di sfida o di lotta. Tuttavia, il tono generale è legger
# --- Fine inferenza su segmento audio ---
#
# Cache CUDA svuotata dopo l'analisi del frammento 5.
#
# --- TUTTE LE RISPOSTE DEI FRAMMENTI ---
#
# Risposta per frammento 1:
# Nel primo segmento della canzone, si sente l'utilizzo di diversi strumenti musicali tra cui un violino, un cello, una tromba e un pianoforte. Questi strumenti creano un senso di tensione e attesa. La velocità del brano è media, con un ritmo incalzante che aumenta l'emozione di aspettativa. Il tono generale del brano è cupo e malinconico, creando un senso di tristezza e ansia. L'immagine che si viene a formare è quella di una notte tempestosa, dove le stelle brillano nel cielo bu
#
# Risposta per frammento 2:
# Nel secondo segmento della canzone, si sente l'utilizzo di diversi strumenti musicali tra cui un pianoforte, una tromba e una chitarra. Questi strumenti creano un mix melodioso e armonioso che contribuisce alla bellezza del brano. La velocità del brano è media, con un ritmo costante che tiene il pubblico incollato alla melodia. Il tono generale del brano è dolce e mellow, creando un senso di serenità e tranquillità. Tuttavia, ci sono momenti in cui la tensione aumenta, causando un senso di agitazione leggera.
#
# Risposta per frammento 3:
# Nel terzo e penultimo segmento della canzone, si sente un brano dal tono dolce e malinconico che sembra evocare un senso di nostalgia. Si sentono due strumenti principali: un pianoforte che suona l'arpeggio principale e un fagotto che ripete una nota costante in corrispondenza con le parole "I'm still here". Questo brano sembra essere stato scritto per rappresentare un momento di riflessione e introspezione, piuttosto che per esprimere una forte emotività. I valori numerici assegnati sono: calma 120, trist
#
# Risposta per frammento 4:
# Nel quarto e quinto segmento dell'audio, si sente un brano rock con un forte impatto emotivo. Sono presenti una chitarra solista, un basso, una batteria e un synth. Il ritmo è veloce e incalzante, creando un senso di tensione e agitazione. Il timbro è pesante e roccioso, tipico del genere rock. Questo brano evoca emozioni forti, come l'ira o la determinazione, grazie alla sua struttura potente e al suo ritmo incalzante. In generale, questo brano sembra essere ideale per situazioni intense e
#
# Risposta per frammento 5:
# Frammento 5/5: In questo momento della canzone, si sente un forte impatto delle percussioni che creano un ritmo incalzante e vigoroso. Si uniscono al suono della chitarra elettrica, che conferisce alla melodia un tono solido e deciso. Il basso e le tastiere completano l'arrangement, creando un sound rock che è allo stesso tempo potente e coinvolgente. Questo brano sembra trasmettere una sensazione di determinazione e forza, che potrebbe ispirare momenti di sfida o di lotta. Tuttavia, il tono generale è legger
#
#
# Processo di analisi audio diviso in esattamente 5 frammenti completato.

# %%
import csv
import matplotlib.pyplot as plt
import re

def parse_rgb_to_normalized_tuple(rgb_string):
    """
    Converte una stringa come "rgb(r, g, b)" in una tupla di float (r, g, b)
    normalizzati nell'intervallo [0, 1] per matplotlib.
    """
    try:
        # Trova tutti i numeri nella stringa usando un'espressione regolare
        numeri = re.findall(r'\d+', rgb_string)
        if len(numeri) == 3:
            # Converte i numeri in interi e li normalizza dividendoli per 255.0
            r = int(numeri[0]) / 255.0
            g = int(numeri[1]) / 255.0
            b = int(numeri[2]) / 255.0
            return (r, g, b)
        else:
            # Ritorna il nero se il formato non è corretto
            return (0, 0, 0)
    except (ValueError, IndexError):
        # Ritorna il nero in caso di errore
        return (0, 0, 0)

def visualizza_colori_canzoni(nome_file_csv, max_canzoni=5):
    """
    Legge un file CSV e visualizza i colori per ogni canzone usando matplotlib.
    Mostra una finestra per ogni canzone, una alla volta.

    Args:
        nome_file_csv (str): Il nome del file CSV da leggere.
        max_canzoni (int): Il numero massimo di canzoni da visualizzare.
    """
    try:
        with open(nome_file_csv, mode='r', newline='', encoding='utf-8') as file:
            lettore_csv = csv.reader(file)
            header = next(lettore_csv) # Salta l'intestazione

            print(f"Sto per visualizzare i colori delle prime {max_canzoni} canzoni.")
            print("Chiudi ogni finestra per procedere alla successiva.")

            canzoni_visualizzate = 0
            for riga in lettore_csv:
                if not riga:
                    continue

                if canzoni_visualizzate >= max_canzoni:
                    print(f"\nVisualizzazione completata. Modifica il parametro 'max_canzoni' per vederne di più.")
                    break

                # Estrae i dati dalla riga del CSV 
                nome_canzone = riga[0]
                colori_stringa = riga[1:7] # Prende i 5 frammenti e il totale

                # Converte le stringhe in colori visualizzabili
                colori = [parse_rgb_to_normalized_tuple(s) for s in colori_stringa]
                
                # Crea la figura e i subplot (1 riga, 6 colonne)
                fig, axes = plt.subplots(1, 6, figsize=(15, 3))
                fig.suptitle(f"Colori per la Canzone: {nome_canzone}", fontsize=16)

                titoli = [f"Frammento {i+1}" for i in range(5)] + ["Totale"]

                for ax, colore, titolo in zip(axes, colori, titoli):
                    # Mostra un riquadro con il colore corrispondente
                    ax.imshow([[colore]])
                    ax.set_title(titolo)
                    # Nasconde gli assi per una visualizzazione più pulita
                    ax.set_xticks([])
                    ax.set_yticks([])

                plt.tight_layout(rect=[0, 0, 1, 0.9]) # Adegua il layout per far spazio al titolo
                plt.show() # Mostra la finestra per la canzone corrente

                canzoni_visualizzate += 1

    except FileNotFoundError:
        print(f"ERRORE: Il file '{nome_file_csv}' non è stato trovato.")
    except ImportError:
        print("ERRORE: La libreria 'matplotlib' non è installata.")
        print("Per favore, installala eseguendo il comando: pip install matplotlib")
    except Exception as e:
        print(f"Si è verificato un errore imprevisto: {e}")


# --- ESECUZIONE DELLO SCRIPT ---
file_da_leggere = '/kaggle/input/valutazione-rgb-segmenti/valutazione_rgb_segmenti.csv'

# Visualizza i colori per le prime 5 canzoni nel file.
# Puoi cambiare questo numero se vuoi vederne di più o di meno.
visualizza_colori_canzoni(file_da_leggere, max_canzoni=5)
# Out:
# Sto per visualizzare i colori delle prime 5 canzoni.
# Chiudi ogni finestra per procedere alla successiva.
# Visualizzazione completata. Modifica il parametro 'max_canzoni' per vederne di più.
