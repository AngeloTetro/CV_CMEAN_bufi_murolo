# %%
import pandas as pd

# Definisci il percorso del file parquet
# Assicurati che 'artgraph_metadata.parquet' sia nella stessa directory del notebook
METADATA_FILE_PATH = 'artgraph_metadata.parquet'

print(f"Tentativo di caricare il file metadati: {METADATA_FILE_PATH}")

try:
    # Carica il file parquet in un DataFrame Pandas
    metadata_df = pd.read_parquet(METADATA_FILE_PATH)
    
    print("\nMetadati caricati con successo!")
    
    # Stampa le prime 3 righe del DataFrame
    print("\n--- Prime 3 righe dei metadati ---")
    print(metadata_df.head(3))
    
    # Stampa i nomi di tutte le colonne disponibili
    print("\n--- Nomi delle colonne disponibili nei metadati ---")
    print(metadata_df.columns.tolist())
    
    # Stampa il numero totale di righe e colonne
    print(f"\nDimensioni del DataFrame: {metadata_df.shape[0]} righe, {metadata_df.shape[1]} colonne.")
    
except FileNotFoundError:
    print(f"\nERRORE: Il file '{METADATA_FILE_PATH}' non è stato trovato.")
    print("Assicurati che il file si trovi nella stessa directory del tuo notebook.")
except Exception as e:
    print(f"\nERRORE inatteso durante il caricamento dei metadati: {e}")

print("\nEsplorazione metadati completata.")
# Out:
# Tentativo di caricare il file metadati: artgraph_metadata.parquet
#
# Metadati caricati con successo!
#
# --- Prime 3 righe dei metadati ---
#                         ArtworkTitle            ArtistName ArtworkYear Period  \
# 0  Menton.&#160;Beach with umbrellas  zinaida-serebriakova        1931   None
# 1                        Autumn Song                  erte        None   None
# 2                           Feathers                  erte        None   None
#
#       Style                                           FileName  \
# 0  art deco  zinaida-serebriakova_menton-beach-with-umbrell...
# 1  art deco                               erte_autumn-song.jpg
# 2  art deco                                  erte_feathers.jpg
#
#                Genre                                           Movement
# 0     genre painting  Mir iskusstva, Neoclassical architecture, Repr...
# 1  symbolic painting                                               None
# 2             design                                               None
#
# --- Nomi delle colonne disponibili nei metadati ---
# ['ArtworkTitle', 'ArtistName', 'ArtworkYear', 'Period', 'Style', 'FileName', 'Genre', 'Movement']
#
# Dimensioni del DataFrame: 116475 righe, 8 colonne.
#
# Esplorazione metadati completata.

# %%
import os
import base64
from pathlib import Path
from PIL import Image
import pandas as pd
from ollama import chat
from io import BytesIO
import re # Necessario per la tokenizzazione delle frasi
import numpy as np # Necessario per np.nan in statistiche future
import torch # Import aggiunto per torch.cuda.empty_cache()
import csv

# --- CONFIGURAZIONE GLOBALE ---
# Percorso alla directory delle immagini
# Assicurati che 'images100' sia la cartella principale contenente le immagini.
IMAGE_SOURCE_DIR = './images100' 

# Modello Ollama da utilizzare
OLLAMA_MODEL = 'qwen2.5vl'

# Limita l'elaborazione alle prime N immagini (metti None per processare tutte le immagini)
IMAGES_TO_PROCESS = None # Imposta a None per processare tutte le immagini

# Numero di frammenti per la griglia 2x2
GRID_ROWS = 2
GRID_COLS = 2
TOTAL_GRID_SEGMENTS = GRID_ROWS * GRID_COLS # Sarà 4

# Numero massimo di token da generare per le descrizioni (modifica qui manualmente per i tuoi test)
MAX_TOKENS = 512 

# Percorso del file metadati
METADATA_FILE_PATH = 'artgraph_metadata.parquet'

# Nome del file CSV di output della Cella 2
MAIN_OUTPUT_CSV_FILENAME = f"analisi_immagini_qwen_2x2_con_metadati_max_tokens_{MAX_TOKENS}.csv"

# Temperatura per la generazione del modello (valori più alti = più creatività, valori più bassi = più deterministico)
TEMPERATURE = 0.7 # <--- NUOVA VARIABILE AGGIUNTA QUI

# --- PROMPT ADATTATI PER LE IMMMAGINI ---
# Questo prompt è progettato per dare priorità assoluta alla descrizione del frammento,
# usando i metadati come contesto informativo secondario, se disponibili.
PROMPT_FRAGMENT_BASE = (
    "Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'immagine.** "
    "Focalizzati attentamente sugli elementi, soggetti, colori, texture, forme e sulla composizione presenti nel frammento. "
    "Non fare inferenze o aggiungere dettagli non direttamente osservabili qui. "
    "Fornisci la tua descrizione in italiano."
)
# Aggiunta una variabile per il contesto metadato che verrà appeso alla fine del prompt base
METADATA_CONTEXT_SUFFIX = (
    " (Contesto: questa porzione fa parte di {metadata_info})."
)

# Nuovo prompt per l'analisi totale dell'immagine
PROMPT_TOTAL_IMAGE_BASE = (
    "Analizza e descrivi l'intera immagine nel suo complesso. "
    "Focalizzati su temi generali, composizione complessiva, interazione tra gli elementi, "
    "e il messaggio o l'emozione che l'opera trasmette. "
    "Non limitarti ai dettagli di singoli frammenti ma offri una visione olistica. "
    "Fornisci la tua descrizione in italiano."
)


# --- FUNZIONI DI UTILITY ---

def encode_image_to_base64(image: Image.Image, size=(256, 256)) -> str:
    """
    Ridimensiona un'immagine PIL e la codifica in base64.
    """
    try:
        img_resized = image.resize(size) 
        
        buffer = BytesIO()
        img_resized.save(buffer, format="JPEG") 
        img_bytes = buffer.getvalue()
        
        return base64.b64encode(img_bytes).decode('utf-8')
    except Exception as e:
        print(f"Errore nella codifica dell'immagine: {e}")
        return None

def split_image_into_grid_segments(image: Image.Image, rows: int, cols: int) -> list[Image.Image]:
    """
    Divide un'immagine PIL in una griglia di segmenti (e.g., 2x2).
    Restituisce i segmenti in ordine di lettura (da sinistra a destra, dall'alto in basso).
    """
    width, height = image.size
    segment_width = width // cols
    segment_height = height // rows
    segments = []
    
    for r in range(rows):
        for c in range(cols):
            left = c * segment_width
            upper = r * segment_height
            right = (c + 1) * segment_width if c < cols - 1 else width
            lower = (r + 1) * segment_height if r < rows - 1 else height
            
            segment = image.crop((left, upper, right, lower))
            segments.append(segment)
            
    return segments

def generate_description_ollama(model_name: str, image_base64: str, prompt: str) -> str:
    """
    Genera una descrizione usando un modello Ollama specifico con un'immagine in base64.
    """
    try:
        response = chat(
            model=model_name,
            messages=[
                {
                    'role': 'user',
                    'content': prompt,
                    'images': [image_base64],
                }
            ],
            options={
                'num_predict': MAX_TOKENS,
                'temperature': TEMPERATURE # Ora TEMPERATURE è definita globalmente
            }
        )
        return response.message.content.strip()
    except Exception as e:
        return f"Errore nell'inferenza con {model_name}: {e}"

# --- VERIFICA DIRECTORY IMMAGINI ---
if not os.path.isdir(IMAGE_SOURCE_DIR):
    print(f"ERRORE: La directory delle immagini '{IMAGE_SOURCE_DIR}' non è stata trovata.")
    print("Assicurati che la cartella 'images100' sia nella stessa directory del notebook e contenga le tue immagini.")

print("Setup completato e funzioni utility caricate.")
# Out:
# Setup completato e funzioni utility caricate.

# %%
# Cella 3: Generazione Descrizioni Immagini con Ollama e Metadati

print(f"\n\n--- INIZIO ANALISI IMMAGINI con {OLLAMA_MODEL} (via Ollama) ---")
print(f"  MAX_TOKENS impostato a: {MAX_TOKENS}")

# Questa lista raccoglierà i dizionari per ogni riga del CSV finale
all_image_descriptions_data = []
processed_images_count = 0

# --- Caricamento e preparazione dei metadati ---
metadata_df = None
metadata_dict = {} # Dizionario per lookup veloce
try:
    # Usa METADATA_FILE_PATH come definito nella Cella 2
    metadata_df = pd.read_parquet(METADATA_FILE_PATH, engine='pyarrow') 
    print(f"\nMetadati '{METADATA_FILE_PATH}' caricati con successo.")
    
    # PULIZIA INIZIALE E AGGRESSIVA DEI METADATI APPENA CARICATI QUI
    # Applica la pulizia a tutte le colonne di tipo 'object' (stringa)
    for col in metadata_df.select_dtypes(include=['object']).columns:
        # Sostituisci newline, ritorni a capo e &#160; con spazi, poi togli spazi extra ai bordi
        metadata_df[col] = metadata_df[col].astype(str).str.replace('\n', ' ').str.replace('\r', ' ').str.replace('&#160;', ' ').str.strip()
        # Rimuovi eventuali spazi doppi per pulizia ulteriore
        metadata_df[col] = metadata_df[col].apply(lambda x: re.sub(r'\s+', ' ', x).strip())

    # Prepara un dizionario per una ricerca efficiente usando 'FileName' come chiave
    metadata_dict = metadata_df.set_index('FileName').to_dict('index')
    print("Metadati preparati per la ricerca rapida tramite 'FileName' e puliti da caratteri speciali.")

except FileNotFoundError:
    print(f"\nAVVISO: File '{METADATA_FILE_PATH}' non trovato. Le descrizioni non saranno arricchite con metadati.")
    metadata_df = None
except Exception as e:
    print(f"\nERRORE nel caricamento/preparazione dei metadati: {e}. Le descrizioni non saranno arricchite con metadati.")
    metadata_df = None
# --- FINE Caricamento Metadati ---

# Ottieni la lista dei file immagine dalla directory delle immagini (IMAGE_SOURCE_DIR definita in Cella 2)
all_image_files_in_dir = [f for f in os.listdir(IMAGE_SOURCE_DIR) if f.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff"))]

# Filtra le immagini in base ai metadati disponibili e applica il limite IMAGES_TO_PROCESS
image_files_to_process = sorted([f for f in all_image_files_in_dir if f in metadata_dict]) 

if IMAGES_TO_PROCESS is not None and IMAGES_TO_PROCESS > 0:
    image_files_to_process = image_files_to_process[:IMAGES_TO_PROCESS]
    print(f"\nLimitato a processare le prime {IMAGES_TO_PROCESS} immagini valide.")
else:
    print(f"\nProcessing tutte le {len(image_files_to_process)} immagini valide nella cartella '{IMAGE_SOURCE_DIR}'.")


if not image_files_to_process:
    print("\nATTENZIONE: Nessuna immagine trovata nella directory specificata che abbia un corrispondente nei metadati. Assicurati che i nomi dei file corrispondano tra la cartella e la colonna 'FileName' del parquet.")
    print("Processo terminato senza immagini da elaborare.")
else:
    for filename in image_files_to_process: 
        image_file_path = os.path.join(IMAGE_SOURCE_DIR, filename)
        print(f"\n--- ELABORAZIONE IMMAGINE: {filename} ({processed_images_count + 1}{f'/{len(image_files_to_process)}' if IMAGES_TO_PROCESS is not None else ''}) ---")

        # Recupero metadati per l'immagine corrente
        image_metadata = metadata_dict.get(filename, {})

        # Estrai i valori dei metadati (già puliti al caricamento del parquet)
        artwork_title = image_metadata.get('ArtworkTitle', '')
        artist_name = image_metadata.get('ArtistName', '')
        artwork_year = image_metadata.get('ArtworkYear', '')
        period = image_metadata.get('Period', '')
        style = image_metadata.get('Style', '')
        genre = image_metadata.get('Genre', '')
        movement = image_metadata.get('Movement', '')

        try:
            original_image = Image.open(image_file_path).convert("RGB")
            print(f"Immagine originale caricata: {filename} (dim: {original_image.size})")

            # --- Costruzione del contesto metadato per i prompt ---
            metadata_info_str = ""
            metadata_parts_list = [] 
            
            # Aggiungi le parti solo se il valore non è una stringa vuota o 'None' testuale (dopo la pulizia)
            if artwork_title and artwork_title.lower() not in ['none', 'sconosciuto']:
                metadata_parts_list.append(f"l'opera '{artwork_title}'")
            if artwork_year and artwork_year.lower() not in ['none', 'sconosciuto']:
                metadata_parts_list.append(f"creata nel {artwork_year}")
            if artist_name and artist_name.lower() not in ['none', 'sconosciuto']:
                metadata_parts_list.append(f"dall'artista {artist_name}")
            if style and style.lower() not in ['none', 'sconosciuto']:
                metadata_parts_list.append(f"nello stile {style}")
            if genre and genre.lower() not in ['none', 'sconosciuto']:
                metadata_parts_list.append(f"e appartenente al genere {genre}")
            if movement and movement.lower() not in ['none', 'sconosciuto']:
                metadata_parts_list.append(f"con il movimento {movement}")

            if metadata_parts_list:
                metadata_info_str = ", ".join(metadata_parts_list)
                print(f"  Contesto metadati generato per '{filename}': '{metadata_info_str}'")
            
            # Combina il prompt base con il contesto metadato (PROMPT_FRAGMENT_BASE, PROMPT_TOTAL_IMAGE_BASE, METADATA_CONTEXT_SUFFIX definiti in Cella 2)
            final_fragment_prompt = PROMPT_FRAGMENT_BASE
            if metadata_info_str:
                final_fragment_prompt += METADATA_CONTEXT_SUFFIX.format(metadata_info=metadata_info_str)
            
            final_total_prompt = PROMPT_TOTAL_IMAGE_BASE
            if metadata_info_str:
                final_total_prompt += METADATA_CONTEXT_SUFFIX.format(metadata_info=metadata_info_str)


            print(f"  Prompt finale per frammenti: {final_fragment_prompt[:100]}...")
            print(f"  Prompt finale per analisi totale: {final_total_prompt[:100]}...")
            # --- FINE Costruzione Prompt ---

            # Frammentazione in 2x2 e descrizione di ciascun segmento (GRID_ROWS, GRID_COLS definiti in Cella 2)
            segments = split_image_into_grid_segments(original_image, rows=GRID_ROWS, cols=GRID_COLS)
            print(f"  Immagine divisa in {len(segments)} segmenti (griglia {GRID_ROWS}x{GRID_COLS}).")

            # Aggiungi le descrizioni dei frammenti
            for i, segment in enumerate(segments):
                print(f"    Generazione descrizione per il segmento {i+1}...")
                base64_segment = encode_image_to_base64(segment, size=(256, 256)) # encode_image_to_base64 definita in Cella 2
                
                fragment_description = ""
                if base64_segment:
                    fragment_description = generate_description_ollama(OLLAMA_MODEL, base64_segment, final_fragment_prompt)
                    # Applica pulizia alla descrizione generata dal modello
                    # Rimuovi newline, ritorni a capo e poi pulisci gli spazi doppi
                    fragment_description = fragment_description.replace('\n', ' ').replace('\r', ' ').strip()
                    fragment_description = re.sub(r'\s+', ' ', fragment_description).strip() # Rimuovi spazi doppi

                    print(f"    Segmento {i+1} Desc: {fragment_description[:100]}...")
                else:
                    fragment_description = f"Errore: Codifica segmento {i+1} fallita."

                # Aggiungi la riga del frammento alla lista dati per il CSV
                row = {
                    "Nome Immagine": filename if i == 0 else '',
                    "ArtworkTitle": artwork_title if i == 0 else '',
                    "ArtistName": artist_name if i == 0 else '',
                    "ArtworkYear": artwork_year if i == 0 else '',
                    "Period": period if i == 0 else '',
                    "Style": style if i == 0 else '',
                    "Genre": genre if i == 0 else '',
                    "Movement": movement if i == 0 else '',
                    "Tipo Descrizione": f"Frammento {i+1}",
                    "Descrizione": fragment_description
                }
                all_image_descriptions_data.append(row)
            
            # Generazione della descrizione per l'intera immagine
            print("  Generazione descrizione per l'intera immagine...")
            base64_full_image = encode_image_to_base64(original_image, size=(512, 512))
            
            full_image_description = ""
            if base64_full_image:
                full_image_description = generate_description_ollama(OLLAMA_MODEL, base64_full_image, final_total_prompt)
                # Applica pulizia alla descrizione generata dal modello
                # Rimuovi newline, ritorni a capo e poi pulisci gli spazi doppi
                full_image_description = full_image_description.replace('\n', ' ').replace('\r', ' ').strip()
                full_image_description = re.sub(r'\s+', ' ', full_image_description).strip() # Rimuovi spazi doppi

                print(f"  Descrizione Totale: {full_image_description[:100]}...")
            else:
                full_image_description = "Errore: Codifica immagine intera fallita."

            # Aggiungi la riga della descrizione totale alla lista dati per il CSV
            row_total = {
                "Nome Immagine": '',
                "ArtworkTitle": '', "ArtistName": '', "ArtworkYear": '', "Period": '', "Style": '', "Genre": '', "Movement": '',
                "Tipo Descrizione": "Totale",
                "Descrizione": full_image_description
            }
            all_image_descriptions_data.append(row_total)
            
        except Exception as e:
            print(f"ERRORE CRITICO durante l'elaborazione dell'immagine {filename}: {e}")
            # Aggiungi righe di errore per frammenti e totale se si verifica un errore
            for i in range(TOTAL_GRID_SEGMENTS): # TOTAL_GRID_SEGMENTS definita in Cella 2
                error_row_fragment = {
                    "Nome Immagine": filename if i == 0 else '',
                    "ArtworkTitle": artwork_title if i == 0 else '',
                    "ArtistName": artist_name if i == 0 else '',
                    "ArtworkYear": artwork_year if i == 0 else '',
                    "Period": period if i == 0 else '',
                    "Style": style if i == 0 else '',
                    "Genre": genre if i == 0 else '',
                    "Movement": movement if i == 0 else '',
                    "Tipo Descrizione": f"Frammento {i+1}",
                    "Descrizione": f"ERRORE NELL'ELABORAZIONE: {e}"
                }
                all_image_descriptions_data.append(error_row_fragment)
            
            error_row_total = {
                "Nome Immagine": '',
                "ArtworkTitle": '', "ArtistName": '', "ArtworkYear": '', "Period": '', "Style": '', "Genre": '', "Movement": '',
                "Tipo Descrizione": "Totale",
                "Descrizione": f"ERRORE NELL'ELABORAZIONE: {e}"
            }
            all_image_descriptions_data.append(error_row_total)

        processed_images_count += 1
        
        # --- Ottimizzazione: Svuota la cache CUDA dopo ogni immagine ---
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            print(f"  Cache CUDA svuotata dopo l'elaborazione di {filename}.")

    # --- DOPO IL LOOP PRINCIPALE, QUANDO TUTTE LE IMMMAGINI SONO STATE PROCESSATE ---

    # Definisci l'ordine delle colonne per il DataFrame finale (fondamentale per il formato)
    column_order = [
        "Nome Immagine",
        "ArtworkTitle",
        "ArtistName",
        "ArtworkYear",
        "Period",
        "Style",
        "Genre",
        "Movement",
        "Tipo Descrizione",
        "Descrizione"
    ]

    # Crea il DataFrame finale dai dati raccolti
    df_output_images = pd.DataFrame(all_image_descriptions_data, columns=column_order)

    print(f"\nProcesso di analisi immagini completato per le prime {processed_images_count} immagini con {OLLAMA_MODEL}.")
    print("DataFrame Pandas 'df_output_images' creato con successo.")

    print("\n--- Anteprima del DataFrame 'df_output_images' ---")
    # Stampa le prime 10 righe per mostrare un esempio di frammenti e analisi totale per una o più immagini
    print(df_output_images.head(10).to_markdown(index=False)) 

    # Salva il DataFrame in un file CSV SENZA la clausola 'quoting='
    # Questo userà il comportamento di quotatura predefinito di Pandas (QUOTE_MINIMAL o equivalente)
    df_output_images.to_csv(MAIN_OUTPUT_CSV_FILENAME, index=False, encoding='utf-8')
    print(f"\nDataFrame salvato come '{MAIN_OUTPUT_CSV_FILENAME}' nella stessa directory del notebook con quotatura predefinita (minimal).")

print("\nProcesso completo terminato.")
# Out:
# --- INIZIO ANALISI IMMAGINI con qwen2.5vl (via Ollama) ---
#   MAX_TOKENS impostato a: 512
#
# Metadati 'artgraph_metadata.parquet' caricati con successo.
# Metadati preparati per la ricerca rapida tramite 'FileName' e puliti da caratteri speciali.
#
# Processing tutte le 100 immagini valide nella cartella './images100'.
#
# --- ELABORAZIONE IMMAGINE: aleksey-savrasov_courtyard-spring-1853.jpg (1) ---
# Immagine originale caricata: aleksey-savrasov_courtyard-spring-1853.jpg (dim: (220, 275))
#   Contesto metadati generato per 'aleksey-savrasov_courtyard-spring-1853.jpg': 'l'opera 'Courtyard. Spring.', creata nel 1853, dall'artista aleksey-savrasov, nello stile realism, e appartenente al genere cityscape, con il movimento Realism (arts)'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra un frammento di un dipinto rappresentante un cortile in primavera. Si può osservar...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra una porzione di un dipinto realistico intitolato "Courtyard. Spring.", realizzato ...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: La porzione dell'immagine mostra un paesaggio urbano in primavera. Si può notare un terreno bagnato ...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione dell'immagine mostra una rappresentazione di un'area esterna che sembra essere un cortil...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "Courtyard. Spring." di Aleksey Savrasov, realizzata nel 1853, è un esempio distintivo dell'...
#
# --- ELABORAZIONE IMMAGINE: alfred-sisley_village-on-the-banks-of-the-seine-1872.jpg (2) ---
# Immagine originale caricata: alfred-sisley_village-on-the-banks-of-the-seine-1872.jpg (dim: (220, 275))
#   Contesto metadati generato per 'alfred-sisley_village-on-the-banks-of-the-seine-1872.jpg': 'l'opera 'Village on the banks of the Seine', creata nel 1872, dall'artista alfred-sisley, nello stile impressionism, e appartenente al genere landscape, con il movimento Impressionism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: La porzione dell'immagine mostra un paesaggio impressionista con un'attenzione particolare alla luce...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: La porzione dell'immagine mostra una vista di un villaggio situato lungo un fiume, probabilmente il ...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Nel frammento dell'immagine, si può osservare un paesaggio impressionistico con sfumature di verde e...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Nel frammento visibile, si possono osservare alcuni elementi caratteristici dell'opera "Village on t...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera intitolata "Village on the banks of the Seine" di Alfred Sisley, realizzata nel 1872, è un e...
#
# --- ELABORAZIONE IMMAGINE: chaldin-alex_lilies.jpg (3) ---
# Immagine originale caricata: chaldin-alex_lilies.jpg (dim: (220, 275))
#   Contesto metadati generato per 'chaldin-alex_lilies.jpg': 'l'opera 'Lilies', dall'artista chaldin-alex, nello stile fauvism, e appartenente al genere flower painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Il frammento dell'opera "Lilies" mostra una composizione vibrante e colorata che è tipica dello stil...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Nel frammento visibile, si possono osservare due fiori di giglio, dipinti con una tecnica astratta e...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra una porzione di un dipinto floreale, caratteristico dello stile fauvismo, con un f...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Nel frammento dell'opera "Lilies" di Chaldin-Alex, si possono notare forme astratte e vibranti che r...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è un'opera d'arte ad olio intitolata "Lilies" di un artista chiamato Chaldin-Alex, realiz...
#
# --- ELABORAZIONE IMMAGINE: currier-and-ives_catching-a-trout-1854.jpg (4) ---
# Immagine originale caricata: currier-and-ives_catching-a-trout-1854.jpg (dim: (220, 275))
#   Contesto metadati generato per 'currier-and-ives_catching-a-trout-1854.jpg': 'l'opera 'Catching a Trout', creata nel 1854, dall'artista currier-and-ives, nello stile romanticism, e appartenente al genere genre painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra una figura maschile in piedi, indossando un abito elegante con una giacca scura, u...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Il frammento dell'immagine raffigura due figure umane che sembrano essere impegnate in un'attività a...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: La porzione visibile dell'immagine mostra un frammento di un dipinto, probabilmente "Catching a Trou...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione dell'immagine mostra due individui impegnati nella pesca di un trota. L'immagine è parte...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "Catching a Trout", realizzata nel 1854 da Currier and Ives, è un esempio tipico del genere ...
#
# --- ELABORAZIONE IMMAGINE: edvard-munch_girl-yawning-1913.jpg (5) ---
# Immagine originale caricata: edvard-munch_girl-yawning-1913.jpg (dim: (220, 275))
#   Contesto metadati generato per 'edvard-munch_girl-yawning-1913.jpg': 'l'opera 'Girl Yawning', creata nel 1913, dall'artista edvard-munch, nello stile expressionism, e appartenente al genere genre painting, con il movimento Expressionism, Symbolism (arts)'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra un dipinto impressionistico che sembra rappresentare una figura umana, probabilmen...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: La porzione dell'immagine mostra un'opera di Edvard Munch, intitolata "Girl Yawning", realizzata nel...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: La porzione visibile dell'immagine raffigura un frammento di un dipinto in stile expressionista, pro...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: L'immagine mostra un frammento di un dipinto in stile espressionista, probabilmente una porzione del...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "Girl Yawning" di Edvard Munch, creata nel 1913, è un esempio tipico dell'expressionismo. La...
#
# --- ELABORAZIONE IMMAGINE: edward-robert-hughes_day.jpg (6) ---
# Immagine originale caricata: edward-robert-hughes_day.jpg (dim: (220, 275))
#   Contesto metadati generato per 'edward-robert-hughes_day.jpg': 'l'opera 'Day', dall'artista edward-robert-hughes, nello stile romanticism, e appartenente al genere portrait'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Questo frammento dell'opera 'Day' di Edward Robert Hughes, nel genere del ritratto e stile del roman...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: In questa porzione dell'immagine, si può osservare un dettaglio del viso di una figura femminile, pr...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra un frammento di un dipinto a olio raffigurante una figura umana, probabilmente in ...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione dell'immagine mostra un profilo di una persona con capelli biondi e occhi che sembrano a...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "Day" di Edward Robert Hughes, appartenente alla tradizione del Romanticismo, è un ritratto ...
#
# --- ELABORAZIONE IMMAGINE: gerard-van-honthorst_diana-with-her-nymphs-1650.jpg (7) ---
# Immagine originale caricata: gerard-van-honthorst_diana-with-her-nymphs-1650.jpg (dim: (220, 275))
#   Contesto metadati generato per 'gerard-van-honthorst_diana-with-her-nymphs-1650.jpg': 'l'opera 'Diana with Her Nymphs', creata nel 1650, dall'artista gerard-van-honthorst, nello stile baroque, e appartenente al genere mythological painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Nel frammento visibile dell'opera "Diana with Her Nymphs" di Gerard van Honthorst, si può osservare ...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: La porzione dell'immagine mostra un frammento di una dipinta barocca dal titolo "Diana with Her Nymp...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra una porzione di un dipinto barocco, raffigurante una figura femminile nuda seduta ...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: In questo frammento dell'opera "Diana with Her Nymphs", il dipinto di Gerard van Honthorst del 1650,...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "Diana con le ninfe", creata nel 1650 da Gerard van Honthorst, è un esempio tipico del gener...
#
# --- ELABORAZIONE IMMAGINE: giorgio-vasari_assumption-of-the-virgin-detail-1.jpg (8) ---
# Immagine originale caricata: giorgio-vasari_assumption-of-the-virgin-detail-1.jpg (dim: (220, 275))
#   Contesto metadati generato per 'giorgio-vasari_assumption-of-the-virgin-detail-1.jpg': 'l'opera 'Assumption of the Virgin (detail)', creata nel 1567, dall'artista giorgio-vasari, nello stile mannerism (late renaissance), e appartenente al genere religious painting, con il movimento Renaissance'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Il frammento della pittura raffigura una porzione di un affresco con un'ampia cornice dorata. Al cen...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: La porzione dell'immagine mostra un frammento di un dipinto religioso in stile manierismo, probabilm...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra un frammento di un dipinto religioso, probabilmente parte dell'opera "Assumption o...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione dell'immagine mostra una parte del dipinto "Assumption of the Virgin (detail)", realizza...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è un dettaglio del dipinto "Assumption of the Virgin", realizzato nel 1567 da Giorgio Vas...
#
# --- ELABORAZIONE IMMAGINE: hans-andersen-brendekilde_en-skovtur-ved-odense-a-1897.jpg (9) ---
# Immagine originale caricata: hans-andersen-brendekilde_en-skovtur-ved-odense-a-1897.jpg (dim: (220, 275))
#   Contesto metadati generato per 'hans-andersen-brendekilde_en-skovtur-ved-odense-a-1897.jpg': 'l'opera 'En Skovtur Ved Odense &#197;', creata nel 1897, dall'artista hans-andersen-brendekilde, nello stile realism, e appartenente al genere genre painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra un frammento di un dipinto che sembra rappresentare un albero in un paesaggio. L'a...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Il frammento dell'immagine sembra essere una porzione di un dipinto di paesaggio, con un'attenzione ...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra un dipinto realistico di Hans Andersen Brendekilde, intitolato "En Skovtur Ved Ode...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: L'immagine mostra una scena di genere realistica di Hans-Andersen-Brendekilde, intitolata "En Skovtu...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "En Skovtur Ved Odense Å" (Un pomeriggio in un parco a Odense), realizzata nel 1897 da Hans ...
#
# --- ELABORAZIONE IMMAGINE: helene-de-beauvoir_untitled-9.jpg (10) ---
# Immagine originale caricata: helene-de-beauvoir_untitled-9.jpg (dim: (220, 275))
#   Contesto metadati generato per 'helene-de-beauvoir_untitled-9.jpg': 'l'opera 'Untitled', dall'artista helene-de-beauvoir, nello stile fauvism, e appartenente al genere genre painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra una porzione di un dipinto ad olio di stile fauvismo intitolato "Untitled" di Hele...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: La porzione visibile dell'opera "Untitled" di Helene De Beauvoir presenta un paesaggio dipinto con s...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Questo frammento di "Untitled" di Helene de Beauvoir è caratterizzato da un'aberrazione di forme e c...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Questo frammento dell'opera "Untitled" di Helene de Beauvoir, nella sua espressione di stile fauvism...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "Untitled" di Helene de Beauvoir esprime con intensità il genere painting e si trova nel con...
#
# --- ELABORAZIONE IMMAGINE: hermann-hendrich_witches-dance.jpg (11) ---
# Immagine originale caricata: hermann-hendrich_witches-dance.jpg (dim: (220, 275))
#   Contesto metadati generato per 'hermann-hendrich_witches-dance.jpg': 'l'opera 'Witches&#39; Dance', dall'artista hermann-hendrich, nello stile romanticism, e appartenente al genere illustration'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra un frammento di una rappresentazione artistica con un forte impiego di colori scur...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Nel frammento dell'immagine "Witches' Dance" di Hermann-Hendrich, si vedono due figure umane in prim...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: La porzione dell'immagine mostra una scena di un'illustrazione di stile romantico, caratteristica de...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Questo frammento dell'opera "Witches' Dance" di Hermann Hendrich, raffigura un paesaggio notturno. S...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è un dipinto dal titolo "Witches' Dance" dell'artista Hermann Hendrich, realizzato nel co...
#
# --- ELABORAZIONE IMMAGINE: hiroshige_2-kasumigaseki-1857.jpg (12) ---
# Immagine originale caricata: hiroshige_2-kasumigaseki-1857.jpg (dim: (220, 275))
#   Contesto metadati generato per 'hiroshige_2-kasumigaseki-1857.jpg': 'l'opera '2. Kasumigaseki', creata nel 1857, dall'artista hiroshige, nello stile ukiyo-e, e appartenente al genere landscape, con il movimento Utagawa school'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Nel frammento dell'immagine, si osserva un'ampia porzione del cielo, che occupa la maggior parte del...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Nel frammento dell'immagine, si può osservare una scena di paesaggio, tipica dell'arte ukiyo-e di Ho...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: La porzione visibile dell'immagine è una scena di paesaggio urbano, tipica dell'arte ukiyo-e. Si ved...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: L'immagine mostra una porzione di un'opera di stile ukiyo-e, realizzata da Hiroshige nel 1857 e inti...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "2. Kasumigaseki" di Hiroshige, creata nel 1857, è un esempio dell'arte ukiyo-e giapponese, ...
#
# --- ELABORAZIONE IMMAGINE: hiroshige_prune-orchard-sun.jpg (13) ---
# Immagine originale caricata: hiroshige_prune-orchard-sun.jpg (dim: (408, 600))
#   Contesto metadati generato per 'hiroshige_prune-orchard-sun.jpg': 'l'opera '30. Plum Park in Kameido', creata nel 1857 ; Japan, dall'artista hiroshige, nello stile ukiyo-e, e appartenente al genere landscape, con il movimento Utagawa school'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra una porzione di un'opera di stile ukiyo-e, probabilmente parte di "30. Plum Park i...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra una porzione di un'opera dell'artista Hiroshige, intitolata "30. Plum Park in Kame...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra un'opera dell'artista Hiroshige, intitolata "30. Plum Park in Kameido", creata nel...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Questa immagine è un frammento di un'opera di stile ukiyo-e, probabilmente realizzato da Hokusai, co...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "30. Plum Park in Kameido", realizzata nel 1857 da Hiroshige, è un esempio tipico dell'arte ...
#
# --- ELABORAZIONE IMMAGINE: ivan-albright_noname-6.jpg (14) ---
# Immagine originale caricata: ivan-albright_noname-6.jpg (dim: (220, 275))
#   Contesto metadati generato per 'ivan-albright_noname-6.jpg': 'l'opera 'There Were No Flowers Tonight', creata nel 1929, dall'artista ivan-albright, nello stile magic realism, e appartenente al genere portrait'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Nella porzione visibile dell'immagine, si osserva una figura umana distesa su un fondo scuro, con un...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Nella porzione dell'immagine visibile, si può osservare un dettaglio di un dipinto rappresentante un...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra un frammento di una rappresentazione che sembra essere una figura umana, con una c...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: In questa porzione dell'immagine, si può osservare una figura umana in un atteggiamento di abbraccio...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è una porzione di un dipinto intitolato "There Were No Flowers Tonight", realizzato nel 1...
#
# --- ELABORAZIONE IMMAGINE: jan-matejko_sigismund-i-the-old.jpg (15) ---
# Immagine originale caricata: jan-matejko_sigismund-i-the-old.jpg (dim: (220, 275))
#   Contesto metadati generato per 'jan-matejko_sigismund-i-the-old.jpg': 'l'opera 'Sigismund I the Old', dall'artista jan-matejko, nello stile romanticism, e appartenente al genere portrait, con il movimento History painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra un ritratto in stile romantico di Sigismund I the Old, opera di Jan Matejko. La fi...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: La porzione dell'immagine mostra un ritratto di un uomo con capelli scuri e lunghi, arricciati sulla...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Il frammento mostra una porzione di un abito scuro, probabilmente di seta o di un tessuto simile, co...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: L'immagine mostra un dettaglio di un'opera d'arte che sembra appartenere al genere del ritratto, pro...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è un ritratto in stile romantico di Sigismund I il Vecchio, opera di Jan Matejko. La comp...
#
# --- ELABORAZIONE IMMAGINE: jan-matejko_song.jpg (16) ---
# Immagine originale caricata: jan-matejko_song.jpg (dim: (220, 275))
#   Contesto metadati generato per 'jan-matejko_song.jpg': 'l'opera 'Song', dall'artista jan-matejko, nello stile romanticism, e appartenente al genere religious painting, con il movimento History painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra una porzione di un dipinto in stile romantico, probabilmente una parte di "Song" d...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Nel frammento dell'immagine, si osserva un dettaglio di un dipinto in stile romantico, probabilmente...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Nel frammento dell'immagine, si vede una mano femminile, leggermente sollevata, che tiene un ramo di...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Nel frammento dell'immagine, si può osservare un dettaglio di una figura femminile in abiti ricchi d...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "Song" di Jan Matejko, un dipinto appartenente al genere del Romanticismo e del religioso, p...
#
# --- ELABORAZIONE IMMAGINE: jan-matejko_stanislaw-august.jpg (17) ---
# Immagine originale caricata: jan-matejko_stanislaw-august.jpg (dim: (220, 275))
#   Contesto metadati generato per 'jan-matejko_stanislaw-august.jpg': 'l'opera 'Stanislaw August', dall'artista jan-matejko, nello stile romanticism, e appartenente al genere portrait, con il movimento History painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: La porzione dell'immagine mostra un dettaglio di una figura umana, probabilmente una testa o parte d...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra una porzione di un dipinto raffigurante un uomo dal profilo laterale. Si può osser...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Questa porzione dell'immagine mostra un dettaglio di un vestito di un soggetto, probabilmente un abi...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Il frammento mostra una porzione del viso di un uomo, probabilmente una parte del ritratto di Stanis...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è una porzione di un dipinto raffigurante Stanisław August Poniatowski, un personaggio st...
#
# --- ELABORAZIONE IMMAGINE: jan-steen_esther-ahasuerus-and-haman-1668.jpg (18) ---
# Immagine originale caricata: jan-steen_esther-ahasuerus-and-haman-1668.jpg (dim: (750, 565))
#   Contesto metadati generato per 'jan-steen_esther-ahasuerus-and-haman-1668.jpg': 'l'opera 'Esther, Ahasuerus, and Haman', creata nel c.1668, dall'artista jan-steen, nello stile baroque, e appartenente al genere religious painting, con il movimento Dutch Golden Age painting'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Nel frammento dell'immagine, si può osservare una scena dinamica e affollata, probabilmente parte di...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Questo frammento di dipinto sembra rappresentare una scena biblica, con vari personaggi in un contes...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Nel frammento visibile dell'opera di Jan Steen, intitolata "Esther, Ahasuerus, and Haman", è possibi...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Il frammento di immagine mostra una figura umana, probabilmente una donna, vestita di un abito ricca...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera 'Esther, Ahasuerus, e Haman', creata intorno al 1668 da Jan Steen, è un esempio di pittura r...
#
# --- ELABORAZIONE IMMAGINE: john-flaxman_illustration-to-the-iliad-1795-25.jpg (19) ---
# Immagine originale caricata: john-flaxman_illustration-to-the-iliad-1795-25.jpg (dim: (220, 275))
#   Contesto metadati generato per 'john-flaxman_illustration-to-the-iliad-1795-25.jpg': 'l'opera 'Illustration to the Iliad', creata nel 1793 - 1795, dall'artista john-flaxman, nello stile neoclassicism, e appartenente al genere illustration, con il movimento Neoclassicism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra due figure umane in un'illustrazione stilizzata, tipica dello stile neoclassico. L...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: La parte visibile dell'immagine mostra un disegno in bianco e nero di tre figure femminili, rapprese...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra un'illustrazione in bianco e nero che sembra rappresentare un personaggio femminil...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: L'immagine mostra una parte di un disegno a matita, probabilmente tratto da "Illustration to the Ili...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine che stai esaminando fa parte di un'illustrazione dal titolo "Illustration to the Iliad" r...
#
# --- ELABORAZIONE IMMAGINE: john-singer-sargent_venice-the-prison.jpg (20) ---
# Immagine originale caricata: john-singer-sargent_venice-the-prison.jpg (dim: (220, 275))
#   Contesto metadati generato per 'john-singer-sargent_venice-the-prison.jpg': 'l'opera 'Venice. The Prison', creata nel c.1903, dall'artista john-singer-sargent, nello stile impressionism, e appartenente al genere cityscape, con il movimento Impressionism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Il frammento mostra un'opera a acquerello con una composizione impressionista che sembra raffigurare...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra una porzione di un dipinto impressionistico intitolato "Venice. The Prison", reali...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: La porzione dell'immagine mostra una rappresentazione impressionistica di una scena urbana, probabil...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Questo frammento dell'opera di John Singer Sargent, intitolata "Venice. The Prison" e creata nel cir...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera 'Venice. The Prison' di John Singer Sargent, realizzata intorno al 1903, è un esempio dell'i...
#
# --- ELABORAZIONE IMMAGINE: john-singer-sargent_villa-de-marlia-a-fountain-1910.jpg (21) ---
# Immagine originale caricata: john-singer-sargent_villa-de-marlia-a-fountain-1910.jpg (dim: (220, 275))
#   Contesto metadati generato per 'john-singer-sargent_villa-de-marlia-a-fountain-1910.jpg': 'l'opera 'Villa de Marlia. A Fountain', creata nel 1910, dall'artista john-singer-sargent, nello stile impressionism, e appartenente al genere landscape, con il movimento Impressionism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: La porzione dell'immagine mostra un dettaglio di una scena paesaggistica, con sfumature di verde, gi...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Questa porzione dell'immagine mostra una porzione di una foresta o di un bosco, dominata da un grand...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: La porzione dell'immagine mostra una rappresentazione di un paesaggio con elementi tipici di uno sti...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: L'immagine mostra un frammento di una scena paesaggistica con elementi impressionistici. Si possono ...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine che vediamo è una porzione di un dipinto intitolato "Villa de Marlia. A Fountain", realiz...
#
# --- ELABORAZIONE IMMAGINE: john-singer-sargent_villa-torlonia-fountain-1907-1.jpg (22) ---
# Immagine originale caricata: john-singer-sargent_villa-torlonia-fountain-1907-1.jpg (dim: (220, 275))
#   Contesto metadati generato per 'john-singer-sargent_villa-torlonia-fountain-1907-1.jpg': 'l'opera 'Villa Torlonia Fountain', creata nel 1907, dall'artista john-singer-sargent, nello stile impressionism, e appartenente al genere landscape, con il movimento Impressionism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Questa porzione dell'immagine mostra un dettaglio di una fontana di una villa, probabilmente una rap...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Il frammento dell'immagine mostra una rappresentazione impressionistica di un paesaggio, probabilmen...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Il frammento dell'immagine mostra una porzione di un paesaggio con toni di verde scuro e marrone. Si...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Questa porzione dell'immagine mostra una sezione di un dipinto in stile impressionista, probabilment...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine rappresenta una porzione della pittura "Villa Torlonia Fountain", creata nel 1907 da John...
#
# --- ELABORAZIONE IMMAGINE: john-singer-sargent_villa-torlonia-fountain-1907-2.jpg (23) ---
# Immagine originale caricata: john-singer-sargent_villa-torlonia-fountain-1907-2.jpg (dim: (220, 275))
#   Contesto metadati generato per 'john-singer-sargent_villa-torlonia-fountain-1907-2.jpg': 'l'opera 'Villa Torlonia Fountain', creata nel 1907, dall'artista john-singer-sargent, nello stile impressionism, e appartenente al genere landscape, con il movimento Impressionism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: La porzione dell'immagine mostra un dettaglio di un paesaggio con tratti tipici dell'impressionismo....
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra un frammento di un paesaggio impressionistico, probabilmente parte di una fontana ...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Il frammento dell'immagine mostra un angolo di una fontana situata all'interno di un giardino. La fo...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione dell'immagine mostra un paesaggio di un ambiente all'aperto, probabilmente una foresta o...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è una porzione di un dipinto intitolato "Villa Torlonia Fountain", realizzato nel 1907 da...
#
# --- ELABORAZIONE IMMAGINE: juan-gris_the-open-book-1925.jpg (24) ---
# Immagine originale caricata: juan-gris_the-open-book-1925.jpg (dim: (220, 275))
#   Contesto metadati generato per 'juan-gris_the-open-book-1925.jpg': 'l'opera 'The Open Book', creata nel 1925, dall'artista juan-gris, nello stile cubism, e appartenente al genere still life, con il movimento Cubism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra una porzione di un dipinto in stile cubista, realizzato nel 1925 da Juan Gris. La ...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: La porzione visibile dell'immagine mostra una sezione di un quadro cubista, con elementi geometrici ...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Il frammento mostra una porzione di un dipinto cubista, probabilmente una tavolozza o un tavolo, con...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione visibile dell'immagine mostra una parte di un'opera d'arte intitolata "The Open Book" di...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "The Open Book" di Juan Gris, creata nel 1925, è un esempio emblematico del movimento cubist...
#
# --- ELABORAZIONE IMMAGINE: juan-gris_the-table-in-front-of-the-picture-1926.jpg (25) ---
# Immagine originale caricata: juan-gris_the-table-in-front-of-the-picture-1926.jpg (dim: (220, 275))
#   Contesto metadati generato per 'juan-gris_the-table-in-front-of-the-picture-1926.jpg': 'l'opera 'The Table in Front of the Picture', creata nel 1926, dall'artista juan-gris, nello stile cubism, e appartenente al genere still life, con il movimento Cubism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Questa immagine mostra un frammento di una tavolozza di dipinti, probabilmente di Juan Gris, in uno ...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Nella porzione dell'immagine, si può osservare una tavola in legno con un bordo scuro e una superfic...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Il frammento dell'immagine mostra un dettaglio di un tavolo dipinto con stile cubista, come si può i...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Nel frammento dell'immagine, si possono osservare alcune parti di un'opera d'arte cubista intitolata...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera "The Table in Front of the Picture" di Juan Gris, realizzata nel 1926, è un esempio tipico d...
#
# --- ELABORAZIONE IMMAGINE: juan-gris_violin-with-fruit-1924.jpg (26) ---
# Immagine originale caricata: juan-gris_violin-with-fruit-1924.jpg (dim: (220, 275))
#   Contesto metadati generato per 'juan-gris_violin-with-fruit-1924.jpg': 'l'opera 'Violin with Fruit', creata nel 1924, dall'artista juan-gris, nello stile cubism, e appartenente al genere still life, con il movimento Cubism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: Questo frammento dell'opera di Juan Gris, intitolato "Violin with Fruit", mostra una composizione st...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra un frammento di un'opera d'arte stilizzata, probabilmente un'interpretazione cubis...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: La porzione dell'immagine mostra una composizione stilizzata, tipica del cubismo, con forme geometri...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione dell'immagine mostra un frammento di una composizione stilizzata, tipica del cubismo, co...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'opera intitolata "Violin with Fruit" di Juan Gris, creata nel 1924, è un esempio significativo del...
#
# --- ELABORAZIONE IMMAGINE: juan-van-der-hamen_abraham-und-die-drei-engel.jpg (27) ---
# Immagine originale caricata: juan-van-der-hamen_abraham-und-die-drei-engel.jpg (dim: (220, 275))
#   Contesto metadati generato per 'juan-van-der-hamen_abraham-und-die-drei-engel.jpg': 'l'opera 'Abraham Und Die Drei Engel', dall'artista juan-van-der-hamen, nello stile baroque, e appartenente al genere religious painting, con il movimento Bodegón, Still life'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra un frammento di un dipinto religioso, probabilmente raffigurante un angelo in una ...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: Nel frammento dell'immagine "Abraham Und Die Drei Engel" di Juan van der Hamen, è visibile un uomo c...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: In questa porzione dell'immagine, si osservano diversi elementi che fanno parte di un dipinto barocc...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: Nella porzione dell'immagine, si può osservare una figura in piedi con un abito a maniche lunghe, di...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è un'opera barocca, "Abraham Und Die Drei Engel", di Juan van der Hamen, un pittore spagn...
#
# --- ELABORAZIONE IMMAGINE: kay-nielsen_the-unicorn-valiant-little-tailor.jpg (28) ---
# Immagine originale caricata: kay-nielsen_the-unicorn-valiant-little-tailor.jpg (dim: (220, 275))
#   Contesto metadati generato per 'kay-nielsen_the-unicorn-valiant-little-tailor.jpg': 'l'opera 'The Unicorn (Valiant Little Tailor)', dall'artista kay-nielsen, nello stile art nouveau (modern), e appartenente al genere illustration, con il movimento Art Nouveau'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: L'immagine mostra un'illustrazione con stile Art Nouveau, caratterizzata da forme curvilinee e detta...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra una porzione di un dipinto in stile Art Nouveau, riconoscibile dal suo stile decor...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: Questo frammento di immagine sembra essere una parte di un'illustrazione in stile Art Nouveau, proba...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione dell'immagine mostra un dettaglio ricco di dettagli che sembra essere ispirato alla trad...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è una parte di un'illustrazione dal titolo "The Unicorn (Valiant Little Tailor)" di Kay N...
#
# --- ELABORAZIONE IMMAGINE: kay-sage_constant-variation-1958.jpg (29) ---
# Immagine originale caricata: kay-sage_constant-variation-1958.jpg (dim: (220, 275))
#   Contesto metadati generato per 'kay-sage_constant-variation-1958.jpg': 'l'opera 'Constant Variation', creata nel 1958, dall'artista kay-sage, nello stile surrealism, e appartenente al genere landscape, con il movimento Surrealism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: La porzione visibile dell'immagine sembra essere una superficie con una textura che ricorda quella d...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra una composizione di tre forme di roccia disposte in un ordine che ricorda una figu...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra un dettaglio di un paesaggio surreale, probabilmente parte di "Constant Variation"...
#     Generazione descrizione per il segmento 4...
#     Segmento 4 Desc: La porzione dell'immagine mostra un dettaglio di una scultura o di un'opera artistica in stile surre...
#   Generazione descrizione per l'intera immagine...
#   Descrizione Totale: L'immagine è un'opera d'arte che fa parte dell'opera "Constant Variation", creata nel 1958 dall'arti...
#
# --- ELABORAZIONE IMMAGINE: kay-sage_le-passage-1956.jpg (30) ---
# Immagine originale caricata: kay-sage_le-passage-1956.jpg (dim: (220, 275))
#   Contesto metadati generato per 'kay-sage_le-passage-1956.jpg': 'l'opera 'Le Passage', creata nel 1956, dall'artista kay-sage, nello stile surrealism, e appartenente al genere genre painting, con il movimento Surrealism'
#   Prompt finale per frammenti: Descrivi in modo conciso ma dettagliato **solo ciò che è visibile in questa specifica porzione dell'...
#   Prompt finale per analisi totale: Analizza e descrivi l'intera immagine nel suo complesso. Focalizzati su temi generali, composizione ...
#   Immagine divisa in 4 segmenti (griglia 2x2).
#     Generazione descrizione per il segmento 1...
#     Segmento 1 Desc: La porzione dell'immagine mostra un'area di sfondo con tonalità grigie, che sembrano scure in alcune...
#     Generazione descrizione per il segmento 2...
#     Segmento 2 Desc: L'immagine mostra una porzione di un dipinto con una figura umana vista di spalle. La testa della pe...
#     Generazione descrizione per il segmento 3...
#     Segmento 3 Desc: L'immagine mostra un frammento di un dipinto con una composizione astratta e surrealista. Il colore ...
# ...
# |                                                          |                                   |                  |               |          |               |           |                | Frammento 3        | La porzione dell'immagine mostra un paesaggio urbano in primavera. Si può notare un terreno bagnato e scuro con tracce di neve rimasta, indicando la stagione. Le forme del terreno sembrano sfumate e somigliano a trucioli o a tracce di neve sospesa, dando un'atmosfera umida e fredda. Sullo sfondo, ci sono elementi di vegetazione scura e sfumata, forse alberi o cespugli, che sono parzialmente oscurati dalla nebbia o dallo sfondo sfocato. La tonalità dei colori è principalmente grigio-blu e verde scuro, conferendo un'atmosfera fredda e umida. La composizione suggerisce un'atmosfera di quiete e isolamento, tipica del Realismo russo dell'epoca.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |                                                          |                                   |                  |               |          |               |           |                | Frammento 4        | La porzione dell'immagine mostra una rappresentazione di un'area esterna che sembra essere un cortile o un giardino, con un forte impatto di tonalità chiare e scure. La composizione è dominata da tonalità di grigio, nero, e qualche sfumatura di verde e marrone, che potrebbero rappresentare terra o pietre. Si possono notare alcune forme irregolari, che potrebbero essere pietre o rocce, disposte in modo disordinato. L'uso del colore è piuttosto sfumato, con un'ombra di morbidezze, che suggerisce un'atmosfera diurna, probabilmente nebbiosa o soffusa, tipica del genere realista. Non sono presenti figure umane o animali, e la composizione sembra essere più focalizzata sulla rappresentazione dell'ambiente naturale piuttosto che su soggetti specifici. La luce sembra diffusa, senza un chiaro punto focale, che crea un effetto di quiete e di solitudine. La texture dell'immagine è sfumata e poco definita, contribuendo al carattere realista e all'atmosfera contemplativa della scena.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |                                                          |                                   |                  |               |          |               |           |                | Totale             | L'opera "Courtyard. Spring." di Aleksey Savrasov, realizzata nel 1853, è un esempio distintivo dell'arte realista. Il quadro ci presenta un cortile di primavera, dipinto con una profondità di campo e un uso di colori pastello che rendono la scena tranquilla e autentica. La composizione dell'opera è incentrata su un cortile recintato, con una porta in ferro battuto che si apre verso l'alto, guidando lo sguardo del osservatore verso lo spazio aperto che si estende sullo sfondo. Il recinto è fatto di un muro alto, che separa l'area interiore del cortile dalla natura circostante. La porta ferroviaria, con le sue linee curve e lineari, contrasta con la struttura rettilinea del muro e dello sfondo, creando un equilibrio dinamico. Nel cortile stesso, l'artista ha dipinto un paesaggio di primavera, con la terra che si colora di verde e marrone, segni di speranza e rinascita. La luce filtrata attraverso le foglie sparse suggerisce un giorno di primavera calmo e soleggiato, con l'aria fresca e la primavera che si diffonde. Questo aspetto della natura, unito alla luce morbida e all'atmosfera tranquilla, conferisce al quadro un senso di quiete e pace. L'interazione tra gli elementi della scena, tra il muro e la porta, la terra e la vegetazione, e tra la luce e la forma, crea un'armonia visiva che trasmette un senso di tranquillità e di calma. Questa scena di primavera, con i suoi dettagli realistici e il suo uso di colori pastello, invita il pubblico a immaginare un ambiente di pace e rinnovamento, caratteristico del periodo primaverile. Il Realismo, nel quale è immersa questa opera, è un movimento artistico che si concentra sulla rappresentazione diretta e precisa della realtà, con un approccio che va oltre il semplice descriv |
# | alfred-sisley_village-on-the-banks-of-the-seine-1872.jpg | Village on the banks of the Seine | alfred-sisley    | 1872          | None     | impressionism | landscape | Impressionism  | Frammento 1        | La porzione dell'immagine mostra un paesaggio impressionista con un'attenzione particolare alla luce e alla sfumatura. Si vede un'ampia vista di un villaggio o di una struttura residenziale, probabilmente una casa, situata sulle rive di un fiume. La casa è dipinta con toni chiari di giallo e marrone, con un tetto a due piani. L'immagine è dominata da un cielo luminoso, con sfumature di blu e bianco, che si riflette nella luce che attraversa i rami di un albero in primo piano. I rami, con foglie verdi, occupano gran parte dell'immagine e creano una sensazione di movimento e profondità, evidenziando la tecnica impressionista dell'artista. La composizione sembra focalizzarsi sul contrasto tra la struttura e il cielo, con l'albero che funge da elemento di riferimento per la prospettiva. La luce sembra provenire da destra, creando ombre e illuminando diversi aspetti dell'immagine con un effetto brillante e vivace.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |                                                          |                                   |                  |               |          |               |           |                | Frammento 2        | La porzione dell'immagine mostra una vista di un villaggio situato lungo un fiume, probabilmente il Seine, come suggerito dal titolo dell'opera. L'immagine è caratterizzata da un uso di colori chiari e pastosi, tipico dell'impressionismo. Sono presenti degli alberi con foglie verdi, che occupano la maggior parte del bordo superiore della scena. Sotto di essi, si intravedono tetti di case con tetti a due piani, probabilmente di colore giallo o crema, che si stagliano contro un cielo parzialmente nuvoloso con sfumature di blu e giallo. Il fiume è solo suggerito, ma la presenza dell'acqua è indiziata dal riflesso della luce e dalla composizione complessiva. La composizione sembra orientata verso un senso di pace e tranquillità, con l'accento sulla luce e sulla forma delle case e degli alberi. Non sono presenti figure umane, il che conferisce un senso di isolamento e calma alla scena.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |                                                          |                                   |                  |               |          |               |           |                | Frammento 3        | Nel frammento dell'immagine, si può osservare un paesaggio impressionistico con sfumature di verde e marrone. Al centro, si trova un piccolo canale o fiume, su cui galleggia una barca con due persone all'interno. La barca è di un grigio scuro, con un tocco di luce riflessa, suggerendo un leggero movimento dell'acqua. Sullo sfondo, si intravedono terreni verdi e rocciosi, probabilmente parte di una collina o di una riva del fiume. La composizione è piuttosto semplice, con linee morbide e colori soffusi che caratterizzano lo stile impressionista. Non si vedono altri dettagli o elementi rilevanti nella porzione visibile.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |                                                          |                                   |                  |               |          |               |           |                | Frammento 4        | Nel frammento visibile, si possono osservare alcuni elementi caratteristici dell'opera "Village on the banks of the Seine" di Alfred Sisley. - **Forme e struttura:** L'immagine mostra un paesaggio con elementi naturali e urbani. Si distinguono alberi di grandi dimensioni, con tronchi chiari e foglie verdi, che occupano una parte significativa del primo piano. Sono visibili anche alcune strutture, probabilmente case, che si estendono sullo sfondo. - **Colori:** Il colore dominante è il verde, rappresentato dalle foglie degli alberi e dall'erba intorno. I toni del verde variano dal verde scuro al verde chiaro, creando un effetto di profondità. Il cielo sembra avere un tono blu-chiaro, suggerendo un giorno soleggiato. - **Texture:** La texture delle foglie degli alberi è evidente, con linee che indicano i vari piani di foglie. Le case sullo sfondo sembrano avere una struttura abbastanza semplice, con colori chiari e linee nette. - **Composizione:** La composizione si allinea orizzontalmente con l'orizzonte che divide l'immagine in due parti: la parte inferiore con l'elemento naturale e la parte superiore con l'elemento urbano. La prospettiva sembra essere quella di un punto di vista lato, con l'artista che si colloca al centro della scena. - **Stile:** Gli elementi visibili sono in linea con lo stile impressionista di Sisley, con un'attenzione alla luce e al colore piuttosto che alla precisione dettagliata. Le ombre e i riflessi di luce sono rappresentati in modo vagamente astratto, conferendo un senso di movimento e di tempo reale. In sintesi, questo frammento della "Village on the banks of the Seine" mostra un'ottima interpretazione dell'impressionismo di Sisley, con un'attenzione alle forme naturali e al colore.     |
# |                                                          |                                   |                  |               |          |               |           |                | Totale             | L'opera intitolata "Village on the banks of the Seine" di Alfred Sisley, realizzata nel 1872, è un esempio impressionista che cattura la bellezza e la tranquillità di una paesaggio rurale. L'artista ha utilizzato una tecnica pittorica che si concentra sulla luce e sul tempo, esprimendo l'atmosfera di un luogo attraverso colori pastello e movimenti sottili. La composizione dell'opera è strutturata in modo da guidare lo sguardo dello spettatore da un elemento all'altro. Le case bianche con tetti rossi si stagliano contro lo sfondo di un cielo luminoso, evidenziando la serenità della giornata. La riva del fiume Seine, che si snoda dolcemente attraverso la scena, introduce uno sfondo naturale. Alcune barche leggere sono ammassate lungo il fiume, aggiungendo dinamismo e un senso di attività leggera al paesaggio. La composizione interagisce con l'intero spazio circostante, creando un'atmosfera di pace e armonia. Le foglie delle piante e alberi in primo piano creano un effetto di filtraggio, dando la sensazione di essere in una posizione di osservazione naturale. Le casette in secondo piano, più distanti, sono disposte in modo che sembrano leggermente allontanarsi verso il fondo della scena, creando una sensazione di profondità. L'opera trasmette un'emozione di pace e quiete, che è tipica dell'impressionismo. Sisley utilizza una paletta di colori chiari e morbidi, catturando l'essenza del luogo senza cedere alla specificità dei dettagli. Il movimento e il tempo sono rappresentati attraverso l'uso di pennellate leggermente disomogenee, che creano una sensazione di movimento e di luce. Questo stile pittorico, insieme alla paesaggistica tranquilla e dolce, crea un'immagine di un villaggio che sembra essere un rif              |
#
# DataFrame salvato come 'analisi_immagini_qwen_2x2_con_metadati_max_tokens_512.csv' nella stessa directory del notebook con quotatura predefinita (minimal).
#
# Processo completo terminato.

# %%
import pandas as pd
import numpy as np
from PIL import Image
import os
import re
from transformers import CLIPProcessor, CLIPModel
import torch
import warnings # Per sopprimere alcuni warning di trasformatori se necessario

print("\n\n--- INIZIO CALCOLO STATISTICHE E ANALISI CLIP DETTAGLIATA ---")

# --- Impostazioni/Configurazione (Assicurati che queste siano allineate con le Celle 2 e 3) ---
# Se stai eseguendo questa cella isolatamente e le variabili non sono globali nel tuo ambiente:
# MAIN_OUTPUT_CSV_FILENAME = f"analisi_immagini_qwen_2x2_con_metadati_max_tokens_512.csv" # Adatta al tuo MAX_TOKENS
# IMAGE_SOURCE_DIR = './images100'
# GRID_ROWS = 2
# GRID_COLS = 2
# TOTAL_GRID_SEGMENTS = GRID_ROWS * GRID_COLS

# Ignora i FutureWarnings da transformers, spesso legati a deprecazioni future
warnings.simplefilter('ignore', FutureWarning)

# --- FUNZIONI DI UTILITY PER LE STATISTICHE DEL TESTO ---

def count_words(text: str) -> int:
    """Conta il numero di parole in una stringa, gestendo valori non stringa."""
    if not isinstance(text, str) or pd.isna(text) or text.strip() == '':
        return 0
    return len(text.split())

def tokenize_sentences(text: str) -> list[str]:
    """
    Tokenizza una stringa in frasi.
    Considera ., !, ? come terminatori di frase.
    """
    if not isinstance(text, str) or pd.isna(text) or text.strip() == '':
        return []
    # Usiamo un lookbehind (?<=[.!?]) per includere il terminatore nella frase.
    # r'\s+' cattura uno o più spazi tra le frasi.
    sentences = re.split(r'(?<=[.!?])\s+', text)
    # Filtra eventuali stringhe vuote o solo spazi risultanti dallo split
    sentences = [s.strip() for s in sentences if s.strip()]
    return sentences

def is_complete_sentence(sentence: str) -> bool:
    """Verifica se una frase è considerata completa (termina con . ! ?)."""
    if not isinstance(sentence, str) or pd.isna(sentence):
        return False
    return sentence.strip().endswith(('.', '!', '?'))

# --- FUNZIONI PER CLIP EMBEDDINGS E SIMILARITÀ ---

# Carica il modello e il processore CLIP una sola volta
clip_model = None
clip_processor = None
device = "cpu"
try:
    print("Caricamento modello CLIP (potrebbe richiedere tempo la prima volta)...")
    clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32") # Modello CLIP comune
    clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
    
    device = "cuda" if torch.cuda.is_available() else "cpu"
    clip_model.to(device)
    print(f"Modello CLIP caricato su: {device}")
    
except Exception as e:
    print(f"ERRORE: Impossibile caricare il modello CLIP. Le metriche di similarità CLIP non saranno calcolate.")
    print(f"Dettagli errore: {e}")

def get_clip_embeddings(image: Image.Image = None, text: str = None) -> torch.Tensor:
    """
    Genera embedding CLIP per un'immagine o un testo.
    Restituisce un tensore PyTorch normalizzato.
    """
    if clip_model is None or clip_processor is None:
        return None

    try:
        if image:
            inputs = clip_processor(images=image, return_tensors="pt").to(device)
            with torch.no_grad():
                embeddings = clip_model.get_image_features(**inputs)
        elif text:
            inputs = clip_processor(text=str(text), return_tensors="pt", padding=True, truncation=True).to(device)
            with torch.no_grad():
                embeddings = clip_model.get_text_features(**inputs)
        else:
            return None
        
        # Normalizza gli embeddings per il calcolo della similarità coseno
        return embeddings / embeddings.norm(p=2, dim=-1, keepdim=True)
    except Exception as e:
        # print(f"Avviso: Errore nella generazione embedding CLIP ({'immagine' if image else 'testo'}): {e}")
        return None

def calculate_cosine_similarity(embedding1: torch.Tensor, embedding2: torch.Tensor) -> float:
    """
    Calcola la similarità coseno tra due embedding normalizzati.
    """
    if embedding1 is None or embedding2 is None:
        return np.nan
    try:
        # Assicurati che gli embedding abbiano la stessa dimensione e non siano tensori 0-dimensionali
        if embedding1.ndim == 0: embedding1 = embedding1.unsqueeze(0)
        if embedding2.ndim == 0: embedding2 = embedding2.unsqueeze(0)
        
        return torch.dot(embedding1.squeeze(), embedding2.squeeze()).item()
    except Exception as e:
        # print(f"Avviso: Errore nel calcolo similarità coseno: {e}")
        return np.nan

# --- FUNZIONE PER DIVIDERE IMMAGINE (Duplicata per autonomia, ma preferibile importarla se il notebook lo permette) ---
def split_image_into_grid_segments(image: Image.Image, rows: int, cols: int) -> list[Image.Image]:
    """
    Divide un'immagine PIL in una griglia di segmenti (e.g., 2x2).
    Restituisce i segmenti in ordine di lettura (da sinistra a destra, dall'alto in basso).
    """
    width, height = image.size
    segment_width = width // cols
    segment_height = height // rows
    segments = []
    
    for r in range(rows):
        for c in range(cols):
            left = c * segment_width
            upper = r * segment_height
            # Gestione dei bordi per assicurarsi che tutti i pixel siano inclusi
            right = (c + 1) * segment_width if c < cols - 1 else width
            lower = (r + 1) * segment_height if r < rows - 1 else height
            
            segment = image.crop((left, upper, right, lower))
            segments.append(segment)
            
    return segments

# --- CARICAMENTO E PREPARAZIONE DATAFRAME ---
df_output = None
try:
    df_output = pd.read_csv(MAIN_OUTPUT_CSV_FILENAME)
    print(f"\nDataFrame '{MAIN_OUTPUT_CSV_FILENAME}' caricato con successo per l'analisi.")
    print(f"Numero di righe nel DataFrame caricato: {len(df_output)}")
except FileNotFoundError:
    print(f"ERRORE: File '{MAIN_OUTPUT_CSV_FILENAME}' non trovato. Assicurati di aver eseguito la Cella 3.")
    exit()
except Exception as e:
    print(f"ERRORE nel caricamento del DataFrame: {e}")
    exit()

# Assicurati che le colonne chiave esistano
required_columns = ["Nome Immagine", "Tipo Descrizione", "Descrizione"]
if not all(col in df_output.columns for col in required_columns):
    print(f"ERRORE: Il DataFrame caricato non contiene tutte le colonne richieste: {required_columns}")
    exit()

# --- RACCOLTA DATI PER STATISTICHE ---
all_total_lengths = []
all_fragment_lengths = []

all_total_sentence_lengths = []
total_complete_sentences = 0
total_incomplete_sentences = 0

all_fragment_sentence_lengths = [] # NUOVA LISTA PER LUNGHEZZE FRASI FRAMMENTI
fragment_complete_sentences = 0    # NUOVO CONTATORE PER FRASI COMPLETE FRAMMENTI
fragment_incomplete_sentences = 0  # NUOVO CONTATORE PER FRASI INCOMPLETE FRAMMENTI

all_clip_similarities_total = []
all_clip_similarities_fragments = []

print("\nAvvio calcolo statistiche e similarità CLIP per ogni immagine...")

# Ottieni i nomi delle immagini uniche che iniziano un blocco (non stringhe vuote)
unique_image_filenames = df_output['Nome Immagine'].dropna().unique().tolist()
# Filtra ulteriormente per rimuovere stringhe vuote se ce ne fossero dopo dropna (improbabile, ma per sicurezza)
unique_image_filenames = [f for f in unique_image_filenames if f.strip() != '']

print(f"Trovate {len(unique_image_filenames)} immagini uniche da analizzare.")

for filename in unique_image_filenames:
    print(f"Analizzando i dati per l'immagine: {filename}")
    
    # Seleziona tutte le righe relative all'immagine corrente (inclusi i frammenti e il totale)
    start_index = df_output[df_output['Nome Immagine'] == filename].index[0]
    next_image_start_indices = df_output.loc[start_index + 1:, 'Nome Immagine'].replace('', np.nan).dropna().index
    
    end_index = len(df_output) 
    if not next_image_start_indices.empty:
        end_index = next_image_start_indices[0]
        
    current_image_block_df = df_output.iloc[start_index:end_index].copy()

    # Recupera la descrizione totale
    total_description_series = current_image_block_df[current_image_block_df['Tipo Descrizione'] == 'Totale']['Descrizione']
    total_description = str(total_description_series.iloc[0]) if not total_description_series.empty else ''
    
    # Recupera le descrizioni dei frammenti
    fragment_descriptions_current_image = []
    for i in range(1, TOTAL_GRID_SEGMENTS + 1):
        fragment_desc_series = current_image_block_df[current_image_block_df['Tipo Descrizione'] == f'Frammento {i}']['Descrizione']
        fragment_description = str(fragment_desc_series.iloc[0]) if not fragment_desc_series.empty else ''
        fragment_descriptions_current_image.append(fragment_description)

    # --- Calcolo Statistiche di Lunghezza (Parole) ---
    total_word_count = count_words(total_description)
    all_total_lengths.append(total_word_count)
    print(f"  Descrizione Totale '{filename}' - Parole: {total_word_count}")

    for fragment_description in fragment_descriptions_current_image:
        fragment_word_count = count_words(fragment_description)
        all_fragment_lengths.append(fragment_word_count)
    # print(f"  Descrizioni Frammenti '{filename}' - Parole Medie: {np.mean([count_words(d) for d in fragment_descriptions_current_image]):.2f}") # Meno verbose in loop

    # --- Calcolo Statistiche Frasi per Descrizioni Totali ---
    sentences = tokenize_sentences(total_description)
    for sentence in sentences:
        all_total_sentence_lengths.append(count_words(sentence))
        if is_complete_sentence(sentence):
            total_complete_sentences += 1
        else:
            total_incomplete_sentences += 1
    # if not sentences: # Meno verbose in loop
    #     print(f"  Avviso: Nessuna frase rilevata nella descrizione totale di '{filename}'.")

    # --- Calcolo Statistiche Frasi per Descrizioni Frammenti (NUOVA SEZIONE) ---
    for fragment_description in fragment_descriptions_current_image:
        fragment_sentences = tokenize_sentences(fragment_description)
        for sentence in fragment_sentences:
            all_fragment_sentence_lengths.append(count_words(sentence))
            if is_complete_sentence(sentence):
                fragment_complete_sentences += 1
            else:
                fragment_incomplete_sentences += 1
        # if not fragment_sentences: # Meno verbose in loop
        #     print(f"  Avviso: Nessuna frase rilevata nella descrizione di un frammento di '{filename}'.")


    # --- Calcolo Similarità CLIP ---
    if clip_model and clip_processor:
        image_file_path = os.path.join(IMAGE_SOURCE_DIR, filename)
        if os.path.exists(image_file_path):
            try:
                original_image = Image.open(image_file_path).convert("RGB")
                
                # Similarità: Immagine Totale vs. Descrizione Totale
                img_total_embedding = get_clip_embeddings(image=original_image)
                text_total_embedding = get_clip_embeddings(text=total_description)
                similarity_total = calculate_cosine_similarity(img_total_embedding, text_total_embedding)
                all_clip_similarities_total.append(similarity_total)
                print(f"  Similarità CLIP Totale '{filename}': {similarity_total:.4f}")

                # Similarità: Frammenti Immagine vs. Descrizioni Frammenti
                segments_images = split_image_into_grid_segments(original_image, rows=GRID_ROWS, cols=GRID_COLS)
                for i, segment_image in enumerate(segments_images):
                    if i < len(fragment_descriptions_current_image):
                        fragment_description_text = fragment_descriptions_current_image[i]
                        img_fragment_embedding = get_clip_embeddings(image=segment_image)
                        text_fragment_embedding = get_clip_embeddings(text=fragment_description_text)
                        similarity_fragment = calculate_cosine_similarity(img_fragment_embedding, text_fragment_embedding)
                        all_clip_similarities_fragments.append(similarity_fragment)
                    else:
                        all_clip_similarities_fragments.append(np.nan) 
            except Exception as e:
                print(f"  ERRORE CLIP per l'immagine '{filename}': {e}. Similarità non calcolate.")
                all_clip_similarities_total.append(np.nan)
                for _ in range(TOTAL_GRID_SEGMENTS):
                    all_clip_similarities_fragments.append(np.nan)
        else:
            print(f"  AVVISO: Immagine '{filename}' non trovata in '{IMAGE_SOURCE_DIR}'. Similarità CLIP non calcolate.")
            all_clip_similarities_total.append(np.nan)
            for _ in range(TOTAL_GRID_SEGMENTS):
                all_clip_similarities_fragments.append(np.nan)
    else:
        print("  CLIP Model/Processor non disponibile. Similarità CLIP non calcolate.")
        all_clip_similarities_total.append(np.nan)
        for _ in range(TOTAL_GRID_SEGMENTS):
            all_clip_similarities_fragments.append(np.nan)
            
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        # print(f"  Cache CUDA svuotata dopo l'analisi CLIP di {filename}.")

print("\n--- RISULTATI STATISTICI FINALI ---")

# --- Funzione helper per stampare statistiche ---
def print_stats(name, data_list):
    if data_list and any(~np.isnan(data_list)):
        valid_data = [d for d in data_list if not np.isnan(d)]
        if valid_data:
            print(f"\n--- Statistiche {name} ---")
            print(f"  Media: {np.mean(valid_data):.2f}")
            print(f"  Minima: {np.min(valid_data):.2f}")
            print(f"  Massima: {np.max(valid_data):.2f}")
            print(f"  Conteggio Validi: {len(valid_data)}")
        else:
            print(f"\n--- Statistiche {name} ---")
            print("  Nessun valore valido per il calcolo.")
    else:
        print(f"\n--- Statistiche {name} ---")
        print("  Lista vuota o solo NaN per il calcolo.")


# --- STAMPA E SALVATAGGIO ---
print_stats("Lunghezza Descrizioni Totali (Parole)", all_total_lengths)
print_stats("Lunghezza Descrizioni Frammenti (Parole)", all_fragment_lengths)

print("\n--- Statistiche Frasi (Descrizioni Totali) ---")
if all_total_sentence_lengths:
    avg_sentence_length_total = np.mean(all_total_sentence_lengths)
    print(f"  Lunghezza media delle frasi (parole): {avg_sentence_length_total:.2f}")

    sentences_below_avg_total = sum(1 for l in all_total_sentence_lengths if l < avg_sentence_length_total)
    sentences_above_avg_total = sum(1 for l in all_total_sentence_lengths if l > avg_sentence_length_total)
    sentences_equal_avg_total = sum(1 for l in all_total_sentence_lengths if l == avg_sentence_length_total)
    
    print(f"  Frasi con lunghezza < media: {sentences_below_avg_total}")
    print(f"  Frasi con lunghezza = media: {sentences_equal_avg_total}")
    print(f"  Frasi con lunghezza > media: {sentences_above_avg_total}")
    print(f"  Numero totale di frasi: {len(all_total_sentence_lengths)}")
    print(f"  Frasi complete: {total_complete_sentences}")
    print(f"  Frasi incomplete: {total_incomplete_sentences}")
else:
    print("  Nessuna frase rilevata per le descrizioni totali.")

# NUOVE STATISTICHE FRASI PER FRAMMENTI
print("\n--- Statistiche Frasi (Descrizioni Frammenti) ---")
if all_fragment_sentence_lengths:
    avg_sentence_length_fragment = np.mean(all_fragment_sentence_lengths)
    print(f"  Lunghezza media delle frasi (parole): {avg_sentence_length_fragment:.2f}")

    sentences_below_avg_fragment = sum(1 for l in all_fragment_sentence_lengths if l < avg_sentence_length_fragment)
    sentences_above_avg_fragment = sum(1 for l in all_fragment_sentence_lengths if l > avg_sentence_length_fragment)
    sentences_equal_avg_fragment = sum(1 for l in all_fragment_sentence_lengths if l == avg_sentence_length_fragment)
    
    print(f"  Frasi con lunghezza < media: {sentences_below_avg_fragment}")
    print(f"  Frasi con lunghezza = media: {sentences_equal_avg_fragment}")
    print(f"  Frasi con lunghezza > media: {sentences_above_avg_fragment}")
    print(f"  Numero totale di frasi: {len(all_fragment_sentence_lengths)}")
    print(f"  Frasi complete: {fragment_complete_sentences}")
    print(f"  Frasi incomplete: {fragment_incomplete_sentences}")
else:
    print("  Nessuna frase rilevata per le descrizioni dei frammenti.")


# Utilizza la funzione print_stats per le similarità CLIP
print_stats("Similarità CLIP (Immagine Totale vs. Descrizione Totale)", all_clip_similarities_total)
print_stats("Similarità CLIP (Frammento Immagine vs. Descrizione Frammento)", all_clip_similarities_fragments)


# --- SALVATAGGIO STATISTICHE IN CSV ---
stats_data = {
    'Metriche': [
        'Lunghezza Media Descrizioni Totali (Parole)', 'Lunghezza Minima Descrizioni Totali (Parole)', 'Lunghezza Massima Descrizioni Totali (Parole)',
        'Lunghezza Media Descrizioni Frammenti (Parole)', 'Lunghezza Minima Descrizioni Frammenti (Parole)', 'Lunghezza Massima Descrizioni Frammenti (Parole)',
        'Lunghezza Media Frasi Totali (Parole)',
        'Frasi < Media (Totali)', 'Frasi = Media (Totali)', 'Frasi > Media (Totali)',
        'Frasi Complete (Totali)', 'Frasi Incomplete (Totali)',
        'Lunghezza Media Frasi Frammenti (Parole)', # NUOVA VOCE
        'Frasi < Media (Frammenti)', # NUOVA VOCE
        'Frasi = Media (Frammenti)', # NUOVA VOCE
        'Frasi > Media (Frammenti)', # NUOVA VOCE
        'Frasi Complete (Frammenti)', # NUOVA VOCE
        'Frasi Incomplete (Frammenti)', # NUOVA VOCE
        'Similarità Media CLIP (Totale)', 'Similarità Minima CLIP (Totale)', 'Similarità Massima CLIP (Totale)',
        'Similarità Media CLIP (Frammenti)', 'Similarità Minima CLIP (Frammenti)', 'Similarità Massima CLIP (Frammenti)'
    ],
    'Valore': [
        np.mean(all_total_lengths) if all_total_lengths else np.nan,
        np.min(all_total_lengths) if all_total_lengths else np.nan,
        np.max(all_total_lengths) if all_total_lengths else np.nan,
        np.mean(all_fragment_lengths) if all_fragment_lengths else np.nan,
        np.min(all_fragment_lengths) if all_fragment_lengths else np.nan,
        np.max(all_fragment_lengths) if all_fragment_lengths else np.nan,
        np.mean(all_total_sentence_lengths) if all_total_sentence_lengths else np.nan,
        sentences_below_avg_total if all_total_sentence_lengths else np.nan,
        sentences_equal_avg_total if all_total_sentence_lengths else np.nan,
        sentences_above_avg_total if all_total_sentence_lengths else np.nan,
        total_complete_sentences,
        total_incomplete_sentences,
        np.mean(all_fragment_sentence_lengths) if all_fragment_sentence_lengths else np.nan, # NUOVO VALORE
        sentences_below_avg_fragment if all_fragment_sentence_lengths else np.nan,          # NUOVO VALORE
        sentences_equal_avg_fragment if all_fragment_sentence_lengths else np.nan,           # NUOVO VALORE
        sentences_above_avg_fragment if all_fragment_sentence_lengths else np.nan,           # NUOVO VALORE
        fragment_complete_sentences,                                                         # NUOVO VALORE
        fragment_incomplete_sentences,                                                       # NUOVO VALORE
        np.mean([s for s in all_clip_similarities_total if not np.isnan(s)]) if all_clip_similarities_total and any(~np.isnan(all_clip_similarities_total)) else np.nan,
        np.min([s for s in all_clip_similarities_total if not np.isnan(s)]) if all_clip_similarities_total and any(~np.isnan(all_clip_similarities_total)) else np.nan,
        np.max([s for s in all_clip_similarities_total if not np.isnan(s)]) if all_clip_similarities_total and any(~np.isnan(all_clip_similarities_total)) else np.nan,
        np.mean([s for s in all_clip_similarities_fragments if not np.isnan(s)]) if all_clip_similarities_fragments and any(~np.isnan(all_clip_similarities_fragments)) else np.nan,
        np.min([s for s in all_clip_similarities_fragments if not np.isnan(s)]) if all_clip_similarities_fragments and any(~np.isnan(all_clip_similarities_fragments)) else np.nan,
        np.max([s for s in all_clip_similarities_fragments if not np.isnan(s)]) if all_clip_similarities_fragments and any(~np.isnan(all_clip_similarities_fragments)) else np.nan
    ]
}

df_stats = pd.DataFrame(stats_data)
stats_output_csv_filename = f"statistiche_descrizioni_max_tokens_{MAX_TOKENS}.csv"
df_stats.to_csv(stats_output_csv_filename, index=False, encoding='utf-8')
print(f"\nStatistiche riassuntive salvate come '{stats_output_csv_filename}'.")

print("\nProcesso di calcolo statistiche e analisi CLIP terminato.")
# Out:
# --- INIZIO CALCOLO STATISTICHE E ANALISI CLIP DETTAGLIATA ---
# Caricamento modello CLIP (potrebbe richiedere tempo la prima volta)...
# Modello CLIP caricato su: cpu
#
# DataFrame 'analisi_immagini_qwen_2x2_con_metadati_max_tokens_512.csv' caricato con successo per l'analisi.
# Numero di righe nel DataFrame caricato: 500
#
# Avvio calcolo statistiche e similarità CLIP per ogni immagine...
# Trovate 100 immagini uniche da analizzare.
# Analizzando i dati per l'immagine: aleksey-savrasov_courtyard-spring-1853.jpg
#   Descrizione Totale 'aleksey-savrasov_courtyard-spring-1853.jpg' - Parole: 284
#   Similarità CLIP Totale 'aleksey-savrasov_courtyard-spring-1853.jpg': 0.2761
# Analizzando i dati per l'immagine: alfred-sisley_village-on-the-banks-of-the-seine-1872.jpg
#   Descrizione Totale 'alfred-sisley_village-on-the-banks-of-the-seine-1872.jpg' - Parole: 260
#   Similarità CLIP Totale 'alfred-sisley_village-on-the-banks-of-the-seine-1872.jpg': 0.3581
# Analizzando i dati per l'immagine: chaldin-alex_lilies.jpg
#   Descrizione Totale 'chaldin-alex_lilies.jpg' - Parole: 280
#   Similarità CLIP Totale 'chaldin-alex_lilies.jpg': 0.2207
# Analizzando i dati per l'immagine: currier-and-ives_catching-a-trout-1854.jpg
#   Descrizione Totale 'currier-and-ives_catching-a-trout-1854.jpg' - Parole: 289
#   Similarità CLIP Totale 'currier-and-ives_catching-a-trout-1854.jpg': 0.2787
# Analizzando i dati per l'immagine: edvard-munch_girl-yawning-1913.jpg
#   Descrizione Totale 'edvard-munch_girl-yawning-1913.jpg' - Parole: 277
#   Similarità CLIP Totale 'edvard-munch_girl-yawning-1913.jpg': 0.2756
# Analizzando i dati per l'immagine: edward-robert-hughes_day.jpg
#   Descrizione Totale 'edward-robert-hughes_day.jpg' - Parole: 214
#   Similarità CLIP Totale 'edward-robert-hughes_day.jpg': 0.2643
# Analizzando i dati per l'immagine: gerard-van-honthorst_diana-with-her-nymphs-1650.jpg
#   Descrizione Totale 'gerard-van-honthorst_diana-with-her-nymphs-1650.jpg' - Parole: 270
#   Similarità CLIP Totale 'gerard-van-honthorst_diana-with-her-nymphs-1650.jpg': 0.2839
# Analizzando i dati per l'immagine: giorgio-vasari_assumption-of-the-virgin-detail-1.jpg
#   Descrizione Totale 'giorgio-vasari_assumption-of-the-virgin-detail-1.jpg' - Parole: 238
#   Similarità CLIP Totale 'giorgio-vasari_assumption-of-the-virgin-detail-1.jpg': 0.3253
# Analizzando i dati per l'immagine: hans-andersen-brendekilde_en-skovtur-ved-odense-a-1897.jpg
#   Descrizione Totale 'hans-andersen-brendekilde_en-skovtur-ved-odense-a-1897.jpg' - Parole: 250
#   Similarità CLIP Totale 'hans-andersen-brendekilde_en-skovtur-ved-odense-a-1897.jpg': 0.2967
# Analizzando i dati per l'immagine: helene-de-beauvoir_untitled-9.jpg
#   Descrizione Totale 'helene-de-beauvoir_untitled-9.jpg' - Parole: 237
#   Similarità CLIP Totale 'helene-de-beauvoir_untitled-9.jpg': 0.2769
# Analizzando i dati per l'immagine: hermann-hendrich_witches-dance.jpg
#   Descrizione Totale 'hermann-hendrich_witches-dance.jpg' - Parole: 274
#   Similarità CLIP Totale 'hermann-hendrich_witches-dance.jpg': 0.2716
# Analizzando i dati per l'immagine: hiroshige_2-kasumigaseki-1857.jpg
#   Descrizione Totale 'hiroshige_2-kasumigaseki-1857.jpg' - Parole: 271
#   Similarità CLIP Totale 'hiroshige_2-kasumigaseki-1857.jpg': 0.3220
# Analizzando i dati per l'immagine: hiroshige_prune-orchard-sun.jpg
#   Descrizione Totale 'hiroshige_prune-orchard-sun.jpg' - Parole: 276
#   Similarità CLIP Totale 'hiroshige_prune-orchard-sun.jpg': 0.3109
# Analizzando i dati per l'immagine: ivan-albright_noname-6.jpg
#   Descrizione Totale 'ivan-albright_noname-6.jpg' - Parole: 238
#   Similarità CLIP Totale 'ivan-albright_noname-6.jpg': 0.2294
# Analizzando i dati per l'immagine: jan-matejko_sigismund-i-the-old.jpg
#   Descrizione Totale 'jan-matejko_sigismund-i-the-old.jpg' - Parole: 268
#   Similarità CLIP Totale 'jan-matejko_sigismund-i-the-old.jpg': 0.2459
# Analizzando i dati per l'immagine: jan-matejko_song.jpg
#   Descrizione Totale 'jan-matejko_song.jpg' - Parole: 271
#   Similarità CLIP Totale 'jan-matejko_song.jpg': 0.2576
# Analizzando i dati per l'immagine: jan-matejko_stanislaw-august.jpg
#   Descrizione Totale 'jan-matejko_stanislaw-august.jpg' - Parole: 276
#   Similarità CLIP Totale 'jan-matejko_stanislaw-august.jpg': 0.2503
# Analizzando i dati per l'immagine: jan-steen_esther-ahasuerus-and-haman-1668.jpg
#   Descrizione Totale 'jan-steen_esther-ahasuerus-and-haman-1668.jpg' - Parole: 270
#   Similarità CLIP Totale 'jan-steen_esther-ahasuerus-and-haman-1668.jpg': 0.3331
# Analizzando i dati per l'immagine: john-flaxman_illustration-to-the-iliad-1795-25.jpg
#   Descrizione Totale 'john-flaxman_illustration-to-the-iliad-1795-25.jpg' - Parole: 276
#   Similarità CLIP Totale 'john-flaxman_illustration-to-the-iliad-1795-25.jpg': 0.2593
# Analizzando i dati per l'immagine: john-singer-sargent_venice-the-prison.jpg
#   Descrizione Totale 'john-singer-sargent_venice-the-prison.jpg' - Parole: 228
#   Similarità CLIP Totale 'john-singer-sargent_venice-the-prison.jpg': 0.3032
# Analizzando i dati per l'immagine: john-singer-sargent_villa-de-marlia-a-fountain-1910.jpg
#   Descrizione Totale 'john-singer-sargent_villa-de-marlia-a-fountain-1910.jpg' - Parole: 277
#   Similarità CLIP Totale 'john-singer-sargent_villa-de-marlia-a-fountain-1910.jpg': 0.3470
# Analizzando i dati per l'immagine: john-singer-sargent_villa-torlonia-fountain-1907-1.jpg
#   Descrizione Totale 'john-singer-sargent_villa-torlonia-fountain-1907-1.jpg' - Parole: 261
#   Similarità CLIP Totale 'john-singer-sargent_villa-torlonia-fountain-1907-1.jpg': 0.3536
# Analizzando i dati per l'immagine: john-singer-sargent_villa-torlonia-fountain-1907-2.jpg
#   Descrizione Totale 'john-singer-sargent_villa-torlonia-fountain-1907-2.jpg' - Parole: 176
#   Similarità CLIP Totale 'john-singer-sargent_villa-torlonia-fountain-1907-2.jpg': 0.3044
# Analizzando i dati per l'immagine: juan-gris_the-open-book-1925.jpg
#   Descrizione Totale 'juan-gris_the-open-book-1925.jpg' - Parole: 270
#   Similarità CLIP Totale 'juan-gris_the-open-book-1925.jpg': 0.3654
# Analizzando i dati per l'immagine: juan-gris_the-table-in-front-of-the-picture-1926.jpg
#   Descrizione Totale 'juan-gris_the-table-in-front-of-the-picture-1926.jpg' - Parole: 225
#   Similarità CLIP Totale 'juan-gris_the-table-in-front-of-the-picture-1926.jpg': 0.3282
# Analizzando i dati per l'immagine: juan-gris_violin-with-fruit-1924.jpg
#   Descrizione Totale 'juan-gris_violin-with-fruit-1924.jpg' - Parole: 263
#   Similarità CLIP Totale 'juan-gris_violin-with-fruit-1924.jpg': 0.3357
# Analizzando i dati per l'immagine: juan-van-der-hamen_abraham-und-die-drei-engel.jpg
#   Descrizione Totale 'juan-van-der-hamen_abraham-und-die-drei-engel.jpg' - Parole: 212
#   Similarità CLIP Totale 'juan-van-der-hamen_abraham-und-die-drei-engel.jpg': 0.2732
# Analizzando i dati per l'immagine: kay-nielsen_the-unicorn-valiant-little-tailor.jpg
#   Descrizione Totale 'kay-nielsen_the-unicorn-valiant-little-tailor.jpg' - Parole: 260
#   Similarità CLIP Totale 'kay-nielsen_the-unicorn-valiant-little-tailor.jpg': 0.3362
# Analizzando i dati per l'immagine: kay-sage_constant-variation-1958.jpg
#   Descrizione Totale 'kay-sage_constant-variation-1958.jpg' - Parole: 250
#   Similarità CLIP Totale 'kay-sage_constant-variation-1958.jpg': 0.2774
# Analizzando i dati per l'immagine: kay-sage_le-passage-1956.jpg
#   Descrizione Totale 'kay-sage_le-passage-1956.jpg' - Parole: 246
#   Similarità CLIP Totale 'kay-sage_le-passage-1956.jpg': 0.3120
# Analizzando i dati per l'immagine: l-s-lowry_a-procession-1929.jpg
#   Descrizione Totale 'l-s-lowry_a-procession-1929.jpg' - Parole: 238
#   Similarità CLIP Totale 'l-s-lowry_a-procession-1929.jpg': 0.3638
# Analizzando i dati per l'immagine: le-corbusier_divinit-baroque-1943-1.jpg
#   Descrizione Totale 'le-corbusier_divinit-baroque-1943-1.jpg' - Parole: 174
#   Similarità CLIP Totale 'le-corbusier_divinit-baroque-1943-1.jpg': 0.2789
# Analizzando i dati per l'immagine: le-corbusier_la-chemin-e-1918.jpg
#   Descrizione Totale 'le-corbusier_la-chemin-e-1918.jpg' - Parole: 241
#   Similarità CLIP Totale 'le-corbusier_la-chemin-e-1918.jpg': 0.2714
# Analizzando i dati per l'immagine: le-corbusier_la-lanterne-et-le-petit-haricot-1930.jpg
#   Descrizione Totale 'le-corbusier_la-lanterne-et-le-petit-haricot-1930.jpg' - Parole: 264
#   Similarità CLIP Totale 'le-corbusier_la-lanterne-et-le-petit-haricot-1930.jpg': 0.3066
# Analizzando i dati per l'immagine: le-corbusier_le-bol-rouge-1919.jpg
#   Descrizione Totale 'le-corbusier_le-bol-rouge-1919.jpg' - Parole: 267
#   Similarità CLIP Totale 'le-corbusier_le-bol-rouge-1919.jpg': 0.3103
# Analizzando i dati per l'immagine: louis-comfort-tiffany_reading-lamp-tulip-design-dome-shape-1906.jpg
#   Descrizione Totale 'louis-comfort-tiffany_reading-lamp-tulip-design-dome-shape-1906.jpg' - Parole: 225
#   Similarità CLIP Totale 'louis-comfort-tiffany_reading-lamp-tulip-design-dome-shape-1906.jpg': 0.2889
# Analizzando i dati per l'immagine: luca-giordano_saint-sebastian-cured-by-irene-1665.jpg
#   Descrizione Totale 'luca-giordano_saint-sebastian-cured-by-irene-1665.jpg' - Parole: 251
#   Similarità CLIP Totale 'luca-giordano_saint-sebastian-cured-by-irene-1665.jpg': 0.3280
# Analizzando i dati per l'immagine: lucas-van-leyden_virgil-in-the-basket-1516.jpg
#   Descrizione Totale 'lucas-van-leyden_virgil-in-the-basket-1516.jpg' - Parole: 281
#   Similarità CLIP Totale 'lucas-van-leyden_virgil-in-the-basket-1516.jpg': 0.3084
# Analizzando i dati per l'immagine: lucian-freud_naked-girl-perched-on-a-chair.jpg
#   Descrizione Totale 'lucian-freud_naked-girl-perched-on-a-chair.jpg' - Parole: 264
#   Similarità CLIP Totale 'lucian-freud_naked-girl-perched-on-a-chair.jpg': 0.3241
# Analizzando i dati per l'immagine: lucian-freud_naked-man-with-his-friend.jpg
#   Descrizione Totale 'lucian-freud_naked-man-with-his-friend.jpg' - Parole: 242
#   Similarità CLIP Totale 'lucian-freud_naked-man-with-his-friend.jpg': 0.3706
# Analizzando i dati per l'immagine: lucian-freud_naked-man-with-rat.jpg
#   Descrizione Totale 'lucian-freud_naked-man-with-rat.jpg' - Parole: 211
#   Similarità CLIP Totale 'lucian-freud_naked-man-with-rat.jpg': 0.3308
# Analizzando i dati per l'immagine: lucian-freud_naked-portrait-1973.jpg
#   Descrizione Totale 'lucian-freud_naked-portrait-1973.jpg' - Parole: 249
#   Similarità CLIP Totale 'lucian-freud_naked-portrait-1973.jpg': 0.3199
# Analizzando i dati per l'immagine: luis-feito_n-mero-148-1959.jpg
#   Descrizione Totale 'luis-feito_n-mero-148-1959.jpg' - Parole: 228
#   Similarità CLIP Totale 'luis-feito_n-mero-148-1959.jpg': 0.2760
# Analizzando i dati per l'immagine: m-c-escher_baby.jpg
#   Descrizione Totale 'm-c-escher_baby.jpg' - Parole: 200
#   Similarità CLIP Totale 'm-c-escher_baby.jpg': 0.2897
# Analizzando i dati per l'immagine: m-c-escher_bookplate-b-g-escher-beer.jpg
#   Descrizione Totale 'm-c-escher_bookplate-b-g-escher-beer.jpg' - Parole: 218
#   Similarità CLIP Totale 'm-c-escher_bookplate-b-g-escher-beer.jpg': 0.3190
# Analizzando i dati per l'immagine: manuel-rivera_mutant-mirror-no-5-1971.jpg
#   Descrizione Totale 'manuel-rivera_mutant-mirror-no-5-1971.jpg' - Parole: 247
#   Similarità CLIP Totale 'manuel-rivera_mutant-mirror-no-5-1971.jpg': 0.2682
# Analizzando i dati per l'immagine: marc-chagall_abdullah-discovered-before-him-1948.jpg
#   Descrizione Totale 'marc-chagall_abdullah-discovered-before-him-1948.jpg' - Parole: 219
#   Similarità CLIP Totale 'marc-chagall_abdullah-discovered-before-him-1948.jpg': 0.3359
# Analizzando i dati per l'immagine: marc-chagall_abraham-and-three-angels-1.jpg
#   Descrizione Totale 'marc-chagall_abraham-and-three-angels-1.jpg' - Parole: 285
#   Similarità CLIP Totale 'marc-chagall_abraham-and-three-angels-1.jpg': 0.3026
# Analizzando i dati per l'immagine: marcel-duchamp_chess-game-1910.jpg
#   Descrizione Totale 'marcel-duchamp_chess-game-1910.jpg' - Parole: 245
#   Similarità CLIP Totale 'marcel-duchamp_chess-game-1910.jpg': 0.3230
# Analizzando i dati per l'immagine: marcel-duchamp_landscape-at-blainville-1902.jpg
#   Descrizione Totale 'marcel-duchamp_landscape-at-blainville-1902.jpg' - Parole: 264
#   Similarità CLIP Totale 'marcel-duchamp_landscape-at-blainville-1902.jpg': 0.3117
# Analizzando i dati per l'immagine: marcel-duchamp_portrait-of-chess-players-1911.jpg
#   Descrizione Totale 'marcel-duchamp_portrait-of-chess-players-1911.jpg' - Parole: 287
#   Similarità CLIP Totale 'marcel-duchamp_portrait-of-chess-players-1911.jpg': 0.3481
# Analizzando i dati per l'immagine: mark-tobey_the-new-day-1945.jpg
#   Descrizione Totale 'mark-tobey_the-new-day-1945.jpg' - Parole: 233
#   Similarità CLIP Totale 'mark-tobey_the-new-day-1945.jpg': 0.3415
# Analizzando i dati per l'immagine: maynard-dixon_the-warriors-1911.jpg
#   Descrizione Totale 'maynard-dixon_the-warriors-1911.jpg' - Parole: 224
#   Similarità CLIP Totale 'maynard-dixon_the-warriors-1911.jpg': 0.3066
# Analizzando i dati per l'immagine: mikhail-larionov_sunset-after-rain.jpg
#   Descrizione Totale 'mikhail-larionov_sunset-after-rain.jpg' - Parole: 261
#   Similarità CLIP Totale 'mikhail-larionov_sunset-after-rain.jpg': 0.3355
# Analizzando i dati per l'immagine: miklos-barabas_pigeon-post-1848.jpg
#   Descrizione Totale 'miklos-barabas_pigeon-post-1848.jpg' - Parole: 281
#   Similarità CLIP Totale 'miklos-barabas_pigeon-post-1848.jpg': 0.2616
# Analizzando i dati per l'immagine: nicholas-krushenick_greenwood-1979.jpg
#   Descrizione Totale 'nicholas-krushenick_greenwood-1979.jpg' - Parole: 267
#   Similarità CLIP Totale 'nicholas-krushenick_greenwood-1979.jpg': 0.2482
# Analizzando i dati per l'immagine: nicholas-krushenick_untitled-1961.jpg
#   Descrizione Totale 'nicholas-krushenick_untitled-1961.jpg' - Parole: 229
#   Similarità CLIP Totale 'nicholas-krushenick_untitled-1961.jpg': 0.2783
# Analizzando i dati per l'immagine: nicholas-krushenick_untitled-1963.jpg
#   Descrizione Totale 'nicholas-krushenick_untitled-1963.jpg' - Parole: 264
#   Similarità CLIP Totale 'nicholas-krushenick_untitled-1963.jpg': 0.2787
# Analizzando i dati per l'immagine: nicholas-krushenick_untitled-1998.jpg
#   Descrizione Totale 'nicholas-krushenick_untitled-1998.jpg' - Parole: 170
#   Similarità CLIP Totale 'nicholas-krushenick_untitled-1998.jpg': 0.2549
# Analizzando i dati per l'immagine: nicholas-roerich_a-bird-with-spread-wings.jpg
#   Descrizione Totale 'nicholas-roerich_a-bird-with-spread-wings.jpg' - Parole: 266
#   Similarità CLIP Totale 'nicholas-roerich_a-bird-with-spread-wings.jpg': 0.2224
# Analizzando i dati per l'immagine: nikolay-bogdanov-belsky_country-boy.jpg
#   Descrizione Totale 'nikolay-bogdanov-belsky_country-boy.jpg' - Parole: 205
#   Similarità CLIP Totale 'nikolay-bogdanov-belsky_country-boy.jpg': 0.2727
# Analizzando i dati per l'immagine: nikolay-bogdanov-belsky_country-boys-1.jpg
#   Descrizione Totale 'nikolay-bogdanov-belsky_country-boys-1.jpg' - Parole: 254
#   Similarità CLIP Totale 'nikolay-bogdanov-belsky_country-boys-1.jpg': 0.3304
# Analizzando i dati per l'immagine: nikolay-bogdanov-belsky_cowboy-2.jpg
#   Descrizione Totale 'nikolay-bogdanov-belsky_cowboy-2.jpg' - Parole: 269
#   Similarità CLIP Totale 'nikolay-bogdanov-belsky_cowboy-2.jpg': 0.2423
# Analizzando i dati per l'immagine: pablo-picasso_the-fool-1904.jpg
#   Descrizione Totale 'pablo-picasso_the-fool-1904.jpg' - Parole: 297
#   Similarità CLIP Totale 'pablo-picasso_the-fool-1904.jpg': 0.2919
# Analizzando i dati per l'immagine: pablo-picasso_the-girls-of-avignon-study-1907.jpg
#   Descrizione Totale 'pablo-picasso_the-girls-of-avignon-study-1907.jpg' - Parole: 264
#   Similarità CLIP Totale 'pablo-picasso_the-girls-of-avignon-study-1907.jpg': 0.2701
# Analizzando i dati per l'immagine: pablo-picasso_the-harem-1906.jpg
#   Descrizione Totale 'pablo-picasso_the-harem-1906.jpg' - Parole: 243
#   Similarità CLIP Totale 'pablo-picasso_the-harem-1906.jpg': 0.2927
# Analizzando i dati per l'immagine: paul-jacoulet_dans-l-isle-de-tinian-marianes-1960.jpg
#   Descrizione Totale 'paul-jacoulet_dans-l-isle-de-tinian-marianes-1960.jpg' - Parole: 258
#   Similarità CLIP Totale 'paul-jacoulet_dans-l-isle-de-tinian-marianes-1960.jpg': 0.3353
# Analizzando i dati per l'immagine: paul-jacoulet_femme-tatouee-de-falalap-ouest-carolines-1935.jpg
#   Descrizione Totale 'paul-jacoulet_femme-tatouee-de-falalap-ouest-carolines-1935.jpg' - Parole: 272
#   Similarità CLIP Totale 'paul-jacoulet_femme-tatouee-de-falalap-ouest-carolines-1935.jpg': 0.2891
# Analizzando i dati per l'immagine: paul-jacoulet_hokkan-zan-seoul-coree-1937.jpg
#   Descrizione Totale 'paul-jacoulet_hokkan-zan-seoul-coree-1937.jpg' - Parole: 260
#   Similarità CLIP Totale 'paul-jacoulet_hokkan-zan-seoul-coree-1937.jpg': 0.2914
# Analizzando i dati per l'immagine: pierre-auguste-renoir_pitcher-1919.jpg
#   Descrizione Totale 'pierre-auguste-renoir_pitcher-1919.jpg' - Parole: 228
#   Similarità CLIP Totale 'pierre-auguste-renoir_pitcher-1919.jpg': 0.3564
# Analizzando i dati per l'immagine: pierre-auguste-renoir_portrait-in-a-pink-dress.jpg
#   Descrizione Totale 'pierre-auguste-renoir_portrait-in-a-pink-dress.jpg' - Parole: 244
#   Similarità CLIP Totale 'pierre-auguste-renoir_portrait-in-a-pink-dress.jpg': 0.3620
# Analizzando i dati per l'immagine: pierre-auguste-renoir_portrait-of-a-girl-1880.jpg
#   Descrizione Totale 'pierre-auguste-renoir_portrait-of-a-girl-1880.jpg' - Parole: 244
#   Similarità CLIP Totale 'pierre-auguste-renoir_portrait-of-a-girl-1880.jpg': 0.3330
# Analizzando i dati per l'immagine: pierre-auguste-renoir_portrait-of-a-little-girl-1880.jpg
#   Descrizione Totale 'pierre-auguste-renoir_portrait-of-a-little-girl-1880.jpg' - Parole: 199
#   Similarità CLIP Totale 'pierre-auguste-renoir_portrait-of-a-little-girl-1880.jpg': 0.3337
# Analizzando i dati per l'immagine: pierre-jacques-pelletier_le-pont-marie-a-paris.jpg
#   Descrizione Totale 'pierre-jacques-pelletier_le-pont-marie-a-paris.jpg' - Parole: 245
#   Similarità CLIP Totale 'pierre-jacques-pelletier_le-pont-marie-a-paris.jpg': 0.3070
# Analizzando i dati per l'immagine: pierre-tal-coat_self-portrait.jpg
#   Descrizione Totale 'pierre-tal-coat_self-portrait.jpg' - Parole: 250
#   Similarità CLIP Totale 'pierre-tal-coat_self-portrait.jpg': 0.2547
# Analizzando i dati per l'immagine: pierre-tal-coat_untitled-1975-1.jpg
#   Descrizione Totale 'pierre-tal-coat_untitled-1975-1.jpg' - Parole: 196
#   Similarità CLIP Totale 'pierre-tal-coat_untitled-1975-1.jpg': 0.2843
# Analizzando i dati per l'immagine: pierre-tal-coat_untitled.jpg
#   Descrizione Totale 'pierre-tal-coat_untitled.jpg' - Parole: 220
#   Similarità CLIP Totale 'pierre-tal-coat_untitled.jpg': 0.2598
# Analizzando i dati per l'immagine: pierre-tal-coat_vol-d-oiseaux-i-1959.jpg
#   Descrizione Totale 'pierre-tal-coat_vol-d-oiseaux-i-1959.jpg' - Parole: 281
#   Similarità CLIP Totale 'pierre-tal-coat_vol-d-oiseaux-i-1959.jpg': 0.2325
# Analizzando i dati per l'immagine: pieter-brueghel-the-younger_conversion-of-saul-1590.jpg
#   Descrizione Totale 'pieter-brueghel-the-younger_conversion-of-saul-1590.jpg' - Parole: 292
#   Similarità CLIP Totale 'pieter-brueghel-the-younger_conversion-of-saul-1590.jpg': 0.3134
# Analizzando i dati per l'immagine: quentin-matsys_portret-van-desiderius-erasmus.jpg
#   Descrizione Totale 'quentin-matsys_portret-van-desiderius-erasmus.jpg' - Parole: 229
#   Similarità CLIP Totale 'quentin-matsys_portret-van-desiderius-erasmus.jpg': 0.3496
# Analizzando i dati per l'immagine: rachel-ruysch_posy-of-flowers-with-a-red-admiral-butterfly-on-a-marble-ledge-1695.jpg
#   Descrizione Totale 'rachel-ruysch_posy-of-flowers-with-a-red-admiral-butterfly-on-a-marble-ledge-1695.jpg' - Parole: 272
#   Similarità CLIP Totale 'rachel-ruysch_posy-of-flowers-with-a-red-admiral-butterfly-on-a-marble-ledge-1695.jpg': 0.3442
# Analizzando i dati per l'immagine: rachel-ruysch_spray-of-flowers-with-a-beetle-on-a-stone-balustrade-1741.jpg
#   Descrizione Totale 'rachel-ruysch_spray-of-flowers-with-a-beetle-on-a-stone-balustrade-1741.jpg' - Parole: 273
#   Similarità CLIP Totale 'rachel-ruysch_spray-of-flowers-with-a-beetle-on-a-stone-balustrade-1741.jpg': 0.3145
# Analizzando i dati per l'immagine: raden-saleh_a-flood-in-java.jpg
#   Descrizione Totale 'raden-saleh_a-flood-in-java.jpg' - Parole: 264
#   Similarità CLIP Totale 'raden-saleh_a-flood-in-java.jpg': 0.2862
# Analizzando i dati per l'immagine: richard-jack_river-scene-with-jetty.jpg
#   Descrizione Totale 'richard-jack_river-scene-with-jetty.jpg' - Parole: 273
#   Similarità CLIP Totale 'richard-jack_river-scene-with-jetty.jpg': 0.3020
# Analizzando i dati per l'immagine: richard-jack_the-honourable-edith-violet-kathleen-agar-robartes.jpg
#   Descrizione Totale 'richard-jack_the-honourable-edith-violet-kathleen-agar-robartes.jpg' - Parole: 243
#   Similarità CLIP Totale 'richard-jack_the-honourable-edith-violet-kathleen-agar-robartes.jpg': 0.2765
# Analizzando i dati per l'immagine: richard-jack_the-return-to-the-front-victoria-railway-station.jpg
#   Descrizione Totale 'richard-jack_the-return-to-the-front-victoria-railway-station.jpg' - Parole: 278
#   Similarità CLIP Totale 'richard-jack_the-return-to-the-front-victoria-railway-station.jpg': 0.3165
# Analizzando i dati per l'immagine: rosalba-carriera_crown-prince-friedrich-christian-of-saxony-1739.jpg
#   Descrizione Totale 'rosalba-carriera_crown-prince-friedrich-christian-of-saxony-1739.jpg' - Parole: 258
#   Similarità CLIP Totale 'rosalba-carriera_crown-prince-friedrich-christian-of-saxony-1739.jpg': 0.2891
# Analizzando i dati per l'immagine: rosalba-carriera_portrait-of-a-young-girl-1708.jpg
#   Descrizione Totale 'rosalba-carriera_portrait-of-a-young-girl-1708.jpg' - Parole: 251
#   Similarità CLIP Totale 'rosalba-carriera_portrait-of-a-young-girl-1708.jpg': 0.3187
# Analizzando i dati per l'immagine: sebastiano-conca_the-education-of-achilles.jpg
#   Descrizione Totale 'sebastiano-conca_the-education-of-achilles.jpg' - Parole: 254
#   Similarità CLIP Totale 'sebastiano-conca_the-education-of-achilles.jpg': 0.2459
# Analizzando i dati per l'immagine: stanley-spencer_the-resurrection-cookham-1927.jpg
#   Descrizione Totale 'stanley-spencer_the-resurrection-cookham-1927.jpg' - Parole: 216
#   Similarità CLIP Totale 'stanley-spencer_the-resurrection-cookham-1927.jpg': 0.3495
# Analizzando i dati per l'immagine: stanley-spencer_the-resurrection-reunion-1.jpg
#   Descrizione Totale 'stanley-spencer_the-resurrection-reunion-1.jpg' - Parole: 217
#   Similarità CLIP Totale 'stanley-spencer_the-resurrection-reunion-1.jpg': 0.3180
# Analizzando i dati per l'immagine: stanley-spencer_the-resurrection-with-the-raising-of-jairus-s-daughter.jpg
#   Descrizione Totale 'stanley-spencer_the-resurrection-with-the-raising-of-jairus-s-daughter.jpg' - Parole: 271
#   Similarità CLIP Totale 'stanley-spencer_the-resurrection-with-the-raising-of-jairus-s-daughter.jpg': 0.3479
# Analizzando i dati per l'immagine: tamara-de-lempicka_portrait-of-kizette-adult-i-1955.jpg
#   Descrizione Totale 'tamara-de-lempicka_portrait-of-kizette-adult-i-1955.jpg' - Parole: 269
#   Similarità CLIP Totale 'tamara-de-lempicka_portrait-of-kizette-adult-i-1955.jpg': 0.3271
# Analizzando i dati per l'immagine: theophile-steinlen_ton-nez-1.jpg
#   Descrizione Totale 'theophile-steinlen_ton-nez-1.jpg' - Parole: 223
#   Similarità CLIP Totale 'theophile-steinlen_ton-nez-1.jpg': 0.2191
# Analizzando i dati per l'immagine: theophile-steinlen_trois-permissionaires-barbus-1916.jpg
#   Descrizione Totale 'theophile-steinlen_trois-permissionaires-barbus-1916.jpg' - Parole: 209
#   Similarità CLIP Totale 'theophile-steinlen_trois-permissionaires-barbus-1916.jpg': 0.2439
# Analizzando i dati per l'immagine: victor-hugo_the-cellist-1856.jpg
#   Descrizione Totale 'victor-hugo_the-cellist-1856.jpg' - Parole: 240
#   Similarità CLIP Totale 'victor-hugo_the-cellist-1856.jpg': 0.2613
# Analizzando i dati per l'immagine: vincent-van-gogh_women-working-in-the-peat-1883.jpg
#   Descrizione Totale 'vincent-van-gogh_women-working-in-the-peat-1883.jpg' - Parole: 237
#   Similarità CLIP Totale 'vincent-van-gogh_women-working-in-the-peat-1883.jpg': 0.3101
# Analizzando i dati per l'immagine: wassily-kandinsky_improvisation-dreamy-1913.jpg
#   Descrizione Totale 'wassily-kandinsky_improvisation-dreamy-1913.jpg' - Parole: 266
#   Similarità CLIP Totale 'wassily-kandinsky_improvisation-dreamy-1913.jpg': 0.3400
# Analizzando i dati per l'immagine: william-henry-huddle_portrait-of-madam-candelaria-1891.jpg
#   Descrizione Totale 'william-henry-huddle_portrait-of-madam-candelaria-1891.jpg' - Parole: 258
#   Similarità CLIP Totale 'william-henry-huddle_portrait-of-madam-candelaria-1891.jpg': 0.2454
# Analizzando i dati per l'immagine: william-hogarth_before-the-seduction-and-after-1731.jpg
#   Descrizione Totale 'william-hogarth_before-the-seduction-and-after-1731.jpg' - Parole: 283
#   Similarità CLIP Totale 'william-hogarth_before-the-seduction-and-after-1731.jpg': 0.3239
#
# --- RISULTATI STATISTICI FINALI ---
#
# --- Statistiche Lunghezza Descrizioni Totali (Parole) ---
#   Media: 249.87
#   Minima: 170.00
#   Massima: 297.00
#   Conteggio Validi: 100
#
# --- Statistiche Lunghezza Descrizioni Frammenti (Parole) ---
#   Media: 133.45
#   Minima: 67.00
#   Massima: 265.00
#   Conteggio Validi: 400
#
# --- Statistiche Frasi (Descrizioni Totali) ---
#   Lunghezza media delle frasi (parole): 21.69
#   Frasi con lunghezza < media: 584
#   Frasi con lunghezza = media: 0
#   Frasi con lunghezza > media: 568
#   Numero totale di frasi: 1152
#   Frasi complete: 1113
#   Frasi incomplete: 39
#
# --- Statistiche Frasi (Descrizioni Frammenti) ---
#   Lunghezza media delle frasi (parole): 19.58
#   Frasi con lunghezza < media: 1453
#   Frasi con lunghezza = media: 0
#   Frasi con lunghezza > media: 1273
#   Numero totale di frasi: 2726
#   Frasi complete: 2725
#   Frasi incomplete: 1
#
# --- Statistiche Similarità CLIP (Immagine Totale vs. Descrizione Totale) ---
#   Media: 0.30
#   Minima: 0.22
#   Massima: 0.37
#   Conteggio Validi: 100
#
# --- Statistiche Similarità CLIP (Frammento Immagine vs. Descrizione Frammento) ---
#   Media: 0.26
#   Minima: 0.18
#   Massima: 0.34
#   Conteggio Validi: 400
#
# Statistiche riassuntive salvate come 'statistiche_descrizioni_max_tokens_512.csv'.
#
# Processo di calcolo statistiche e analisi CLIP terminato.
